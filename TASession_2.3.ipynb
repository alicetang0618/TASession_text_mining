# %% [markdown]
# ## 1. Get text from web

# %%
import urllib.request, time, re, random, hashlib, nltk
from bs4 import BeautifulSoup as bs
# %matplotlib notebook

# %%
## Compassionate Caching
# THIS WILL ENSURE THAT PAGES ARE CACHED AS FILES IN YOUR DIRECTORY, AND AVOID UNNECESSARY LOAD ON WEBSITES.  
# ALSO WHEN PAGES ARE ACTUALLY LOADED, THE REQUESTS ARE STAGGERED AS EXPECTED OF HUMAN BROWSING.
last_fetched_at = None

def fetch(url):
    """Load the url compassionately."""
    
    global last_fetched_at
    
    url_hash = hashlib.sha1(url.encode()).hexdigest()
    filename = 'cache-file-{}'.format(url_hash)
    try:
        with open(filename, 'r') as f:
            result = f.read()
            if len(result) > 0:
                print("Retrieving from cache:", url)
                return result
    except:
        pass
    
    print("Loading:", url)
    wait_interval = random.randint(3000,10000)
    if last_fetched_at is not None:
        now = time.time()
        elapsed = now - last_fetched_at
        if elapsed < wait_interval:
            time.sleep((wait_interval - elapsed)/1000)
        
    user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
    headers = { 'User-Agent' : user_agent }
    req = urllib.request.Request(url, headers = headers)
    last_fetched_at = time.time()
    with urllib.request.urlopen(req) as response:
        result = str(response.read())
        with open(filename, 'w') as f:
            f.write(result)
        return result

# %%
fetch('http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/')
# Out:
# Retrieving from cache: http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/
# 'b\'<!doctype html><!--[if IE 8]><html class="no-js lt-ie10 lt-ie9" lang="en"><![endif]--><!--[if IE 9]><html class="no-js lt-ie10" lang="en"><![endif]--><!--[if gt IE 10]><!--><html class="no-js" lang="en"  itemscope itemtype="http://schema.org/NewsArticle" ><!--<![endif]--><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><title>Trump: New Hampshire \\\'probably suits me better\\\'</title><meta content="text/html; charset=UTF-8" name="Content-Type" /><meta name="google" content="notranslate"><meta name="description" itemprop="description" content="Finishing second? It&#39;s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses."><link rel="canonical" href="http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/"><meta property="fb:app_id" content="215046668549694"/><meta property="og:site_name" content="USA TODAY" /><meta name="ROBOTS" content="NOODP, NOYDIR" /><meta property="og:image" content="http://www.gannett-cdn.com/-mm-/341070c63f94c401d71e3071bcabf7ba2c35564c/c=0-125-3802-2273&amp;r=x633&amp;c=1600x630/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/><meta property="og:image:width" content="1600" /><meta property="og:image:height" content="630" /><meta itemprop="thumbnailUrl" content="http://www.gannett-cdn.com/-mm-/a9b1c8ab5d1f0e2c8d37e206f01f157777734d16/c=811-0-3349-2538&amp;r=x153&amp;c=150x150/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/><meta itemprop="thumbnailHeight" content="150"/><meta itemprop="thumbnailWidth" content="150"/><meta itemprop="image" content="http://www.gannett-cdn.com/-mm-/662f67e3f37f6175236b8c874168e9654598fb28/c=811-0-3349-2538&amp;r=x203&amp;c=200x200/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:image:src" content="http://www.gannett-cdn.com/-mm-/310cb64b10c34935ac6c5acbea066dcdb3550c3a/c=0-125-3802-2273&amp;r=x453&amp;c=800x450/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg" /><meta itemprop="dateModified" content="2016-02-03T08:41:44.6900000"/><meta itemprop="datePublished" content="2016-02-02T20:15:29.2170000"/><meta itemprop="articleSection" content="news,politics,onpolitics"/><meta name="twitter:site" content="@usatoday" /><meta name="twitter:creator" content="@usatoday" /><meta name="twitter:title" content="Trump: New Hampshire &#39;probably suits me better&#39;" /><meta name="twitter:description" content="Finishing second? It&#39;s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses." /><meta property="og:title" content="Trump: New Hampshire \\\'probably suits me better\\\'"/><meta property="og:description" content="Finishing second? It&#39;s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses."/><meta property="og:url" content="http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/"/><meta property="og:type" content="article"/><meta name="news_keywords" content="Donald Trump, Iowa caucuses, New Hampshire primary, Republicans" /><meta name="cXenseParse:recs:articleid" content="79726718" /><meta name="cXenseParse:pageclass" content="article" /><meta name="cXenseParse:recs:publishtime" content="2016-02-03T08:41:44.6900000" /><meta name="cXenseParse:recs:category" content="news/politics/onpolitics" /><meta name="cXenseParse:title" content="Trump: New Hampshire &#39;probably suits me better&#39;" /><meta name="cXenseParse:author" content="Susan Page" /><meta name="cXenseParse:recs:contenttype" content="story" /><meta name="cXenseParse:gci_asset_type ...

# %%
## Search for articles with a certain topic
# First, get the page with search results
def get_search_results(entity):
    """Return an html with search results for given entity."""

    result = fetch('http://www.usatoday.com/search/' + entity.replace(" ", "%20") + '/')
    
    return result

# %%
results_html = get_search_results("donald trump")
results_html
# Out:
# Retrieving from cache: http://www.usatoday.com/search/donald%20trump/
# 'b\'<!doctype html><!--[if IE 8]><html class="no-js lt-ie10 lt-ie9" lang="en"><![endif]--><!--[if IE 9]><html class="no-js lt-ie10" lang="en"><![endif]--><!--[if gt IE 10]><!--><html class="no-js" lang="en" ><!--<![endif]--><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><title>USA TODAY</title><meta content="text/html; charset=UTF-8" name="Content-Type" /><meta name="google" content="notranslate"><meta property="fb:app_id" content="215046668549694"/><meta property="og:site_name" content="USA TODAY" /><meta name="ROBOTS" content="NOODP, NOYDIR" /><meta name="cXenseParse:pageclass" content="frontpage" /><meta name="cXenseParse:recs:category" content="search" /><meta name="cXenseParse:title" content="Search Results for &quot;donald trump&quot;" /><meta name="cXenseParse:recs:contenttype" content="search-results" /><meta name="cXenseParse:gci_asset_type" content="search-results" /><meta name="viewport" content="width=1070" /><link rel="shortcut icon" href="http://www.gannett-cdn.com/sites/usatoday/images/favicon.png"><!--[if gt IE 9]><!--><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/main_modern.min.css"><!--<![endif]--><!--[if IE 9]><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/common.min.css"><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/main.min.css"><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/dynamic.min.css"><![endif]--><!--[if IE 8]><link data-identifier="main" rel="stylesheet" href="/static/usat-web-static-1842.0/css/bundles/common.min.css"><link data-identifier="main" rel="stylesheet" href="/static/usat-web-static-1842.0/css/bundles/main.min.css"><link data-identifier="main" rel="stylesheet" href="/static/usat-web-static-1842.0/css/bundles/dynamic.min.css"><![endif]--><link rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/print.css" media="print"><!--[if gt IE 8]><!--><style>\\n        .home-theme-bg, .home-theme-bg-hover:hover, .site-nav-span.site-nav-home-span.site-nav-active-span, .noimage .headline-asset-item-tile.headline-asset-item-home-tile, .parent-label.home { background-color: rgb(24, 119, 182) !important; } .card-suspender-color.home { background: rgb(24, 119, 182) !important; } .headline-asset-item-tile.headline-asset-item-home-tile { background-color: rgb(24, 119, 182); background-color: rgba(0,0,0,0.5); } .listview .noimage .headline-asset-item-tile.headline-asset-item-home-tile, .listview .headline-asset-item-tile.headline-asset-item-home-tile, .listview .hgpm-link.home-theme-bg-hover, .listview .hgpm-link.home-theme-border-hover:hover { background-color: transparent !important; background-color: rgba(0,0,0,0) !important; } .home-theme-color, .hgpm-list-text .home-theme-color .theme-bg-ssts-label, .hgpm-list-text .hgpm-section > .home-theme-color, .blog-asset-double-wide.home-theme-color .presto-h1, .blog-asset-double-wide.home-theme-color .presto-h2, .blog-asset-double-wide.home-theme-color .presto-h3, .blog-asset-double-wide.home-theme-color .presto-h4, .blog-asset-double-wide.home-theme-color .presto-h5, .blog-asset-double-wide.home-theme-color .presto-h6, .home-theme-color > .shbfm-subnav-link:hover, .home-theme-color > .shbfm-subnav-link.is-selected, .home-theme-color .inline-share-count-blog { color: rgb(24, 119, 182); } .blog-asset-double-wide.home-theme-color blockquote { border-color: rgb(24, 119, 182); } .footer > nav > .fronts > section.home h6 { border-color: rgb(24, 119, 182) !important; } .news-theme-bg, .news-theme-bg-hover:hover, .site-nav-span.site-nav-news-span.site-nav-active-span, .noimage .headline-asset-item-tile.headline-asset-item-news-tile, .parent-label.news { background-color: rgb(24, 119, 182) !important; } .card-suspender-color.news { ...

# %%
# Get a list of article urls from the search result page
def get_articles(results_html, n=3):
    """Return a list of article htmls for given search results html."""
    
    articles = []
    soup = bs(results_html, 'lxml')
    tag_set = soup.find_all('a', class_='search-result-item-link')
    for a in tag_set:
        sub_link = a.get('href')
        # exclude the links for videos
        if not sub_link.startswith('/videos/'):
            if sub_link.startswith('http'):
                articles.append(fetch(sub_link))
            else:
                articles.append(fetch('http://www.usatoday.com' + sub_link))
            if len(articles) >= n:
                break
            
    return articles[:n]

# %%
soup = bs(results_html, 'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    b'
#    <!DOCTYPE html>
#    <!--[if IE 8]><html class="no-js lt-ie10 lt-ie9" lang="en"><![endif]-->
#    <!--[if IE 9]><html class="no-js lt-ie10" lang="en"><![endif]-->
#    <!--[if gt IE 10]><!-->
#    <!--<![endif]-->
#   </p>
#   <title>
#    USA TODAY
#   </title>
#   <meta content="text/html; charset=UTF-8" name="Content-Type"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="215046668549694" property="fb:app_id"/>
#   <meta content="USA TODAY" property="og:site_name"/>
#   <meta content="NOODP, NOYDIR" name="ROBOTS"/>
#   <meta content="frontpage" name="cXenseParse:pageclass"/>
#   <meta content="search" name="cXenseParse:recs:category"/>
#   <meta content='Search Results for "donald trump"' name="cXenseParse:title"/>
#   <meta content="search-results" name="cXenseParse:recs:contenttype"/>
#   <meta content="search-results" name="cXenseParse:gci_asset_type"/>
#   <meta content="width=1070" name="viewport"/>
#   <link href="http://www.gannett-cdn.com/sites/usatoday/images/favicon.png" rel="shortcut icon"/>
#   <!--[if gt IE 9]><!-->
#   <link data-identifier="main" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/main_modern.min.css" rel="stylesheet"/>
#   <!--<![endif]-->
#   <!--[if IE 9]><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/common.min.css"><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/main.min.css"><link data-identifier="main" rel="stylesheet" href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/bundles/dynamic.min.css"><![endif]-->
#   <!--[if IE 8]><link data-identifier="main" rel="stylesheet" href="/static/usat-web-static-1842.0/css/bundles/common.min.css"><link data-identifier="main" rel="stylesheet" href="/static/usat-web-static-1842.0/css/bundles/main.min.css"><link data-identifier="main" rel="stylesheet" href="/static/usat-web-static-1842.0/css/bundles/dynamic.min.css"><![endif]-->
#   <link href="http://www.gannett-cdn.com/static/usat-web-static-1842.0/css/print.css" media="print" rel="stylesheet"/>
#   <!--[if gt IE 8]><!-->
#   <style>
#    \n        .home-theme-bg, .home-theme-bg-hover:hover, .site-nav-span.site-nav-home-span.site-nav-active-span, .noimage .headline-asset-item-tile.headline-asset-item-home-tile, .parent-label.home { background-color: rgb(24, 119, 182) !important; } .card-suspender-color.home { background: rgb(24, 119, 182) !important; } .headline-asset-item-tile.headline-asset-item-home-tile { background-color: rgb(24, 119, 182); background-color: rgba(0,0,0,0.5); } .listview .noimage .headline-asset-item-tile.headline-asset-item-home-tile, .listview .headline-asset-item-tile.headline-asset-item-home-tile, .listview .hgpm-link.home-theme-bg-hover, .listview .hgpm-link.home-theme-border-hover:hover { background-color: transparent !important; background-color: rgba(0,0,0,0) !important; } .home-theme-color, .hgpm-list-text .home-theme-color .theme-bg-ssts-label, .hgpm-list-text .hgpm-section > .home-theme-color, .blog-asset-double-wide.home-theme-color .presto-h1, .blog-asset-double-wide.home-theme-color .presto-h2, .blog-asset-double-wide.home-theme-color .presto-h3, .blog-asset-double-wide.home-theme-color .presto-h4, .blog-asset-double-wide.home-theme-color .presto-h5, .blog-asset-double-wide.home-theme-color .presto-h6, .home-theme-color > .shbfm-subnav-link:hover, .home-theme-color > .shbfm-subnav-link.is-selected, .home-theme-color .inline-share-count-blog { color: rgb(24, 119, 182); } .blog-asset-double-wide.home-theme-color blockquote { border-color: rgb(24, 119, 182); } .footer > nav > .fronts > section.home h6 { border-color: rgb(24, 119, 182) !important; } .news-theme-bg, .news-theme-bg-hover:hover, .site-nav-span.site-nav-news-span.site-nav-active-span, .noimage .headline-asset-item-tile.headline-asset-item-news-tile, .parent-label.news { background-color: rgb(24, 119, 182) !important; } .card-suspender-color.news { background: rgb(24, 119, 182) !important; } .headline-asset-item-tile.headline-asset-item-news-tile { background-color: rgb(24, 119, 182); background-color: rgba(0,0,0,0.5); } .listview .noimage .headline-asset-item-tile.headline-asset-item-news-tile, .listview .headline-asset-item-tile.headline-asset-item-news-tile, .listview .hgpm-link.news-theme-bg-hover, .listview .hgpm-link.news-theme-border-hover:hover { background-color: transparent !important; background-color: rgba(0,0,0,0) !important; } .news-theme-color, .hgpm-list-text .news-theme-color .theme-bg-ssts-label, .hgpm-list-text .hgpm-section > .news-theme-color, .blog-asset-double-wide.news-theme-color .presto-h1, .blog-asset-double-wide.news-theme-color .presto-h2, .blog-asset-double-wide.news-theme-color .presto-h3, .blog-asset-double-wide.news-theme-color .presto-h4, .blog-asset-double-wide.news-theme-color .presto-h5, .blog-asset-double-wide.news-theme-color .presto-h6, .news-theme-color > .shbfm-subnav-link:hover, .news-theme-color > .shbfm-subnav-link.is-selected, .news-theme-color .inline-share-count-blog { color: rgb(24, 119, 182); } .blog-asset-double-wide.news-theme-color blockquote { border-color: rgb(24, 119, 182); } .footer > nav > .fronts > section.news h6 { border-color: rgb(24, 119, 182) !important; } .weather-theme-bg, .weather-theme-bg-hover:hover, .site-nav-span.site-nav-weather-span.site-nav-active-span, .noimage .headline-asset-item-tile.headline-asset-item-weather-tile, .parent-label.weather { background-color: rgb(221, 157, 13)) !important; } .card-suspender-color.weather { background: rgb(221, 157, 13)) !important; } .headline-asset-item-tile.headline-asset-item-weather-tile { background-color: rgb(221, 157, 13)); background-color: rgba(0,0,0,0.5); } .listview .noimage .headline-asset-item-tile.headline-asset-item-weather-tile, .listview .headline-asset-item-tile.headline-asset-item-weather-tile, .listview .hgpm-link.weather-theme-bg-hover, .listview .hgpm-link.weather-theme-border-hover:hover { background-color: transparent !important; background-color: rgba(0,0,0,0) !important; } .weather-theme-color, .hgpm-list-text .weather-theme-color  ...
#   </style>
#   <!--<![endif]-->
#   <!--[if lt IE 9]><link rel="stylesheet" href="/services/css/configs.css"><![endif]-->
#   <style>
#   </style>
#   <!--[if lt IE 9]><script src="http://www.gannett-cdn.com/static/usat-web-static-1842.0/js/libs/html5shiv-printshiv.js"></script><script src="http://www.gannett-cdn.com/static/usat-web-static-1842.0/js/libs/respond/respond.min.js"></script><![endif]-->
#   <script type="text/javascript">
#    \n        window.site_vars = {"ugc": {"DEFAULT_AVATAR": "http://emblemsbf.com/img/11864.jpg", "SUNSETTING": true, "tempo_appservice": "http://appserv-ugc.awsprod.usatoday.com/v1", "tempo": false, "gup_yourtake_login": "", "gup_yourtake_user": ""}, "property_type": "publishing", "aws_site_name": "usat", "display_name": "USA TODAY", "market_id": "USAT", "base_url": "usatoday.com", "WEATHER": {}, "DATASPHERE": {}, "siteid": 1, "sections": "news|sports|life|money|tech|travel|opinion|weather|home|marketplace|elections-2016", "userAuthentication": {"login": {"url": "https://login.usatoday.com/USAT-GUP/authenticate/", "cancel_qsp": "cancel-url", "success_qsp": "success-url"}, "logout": {"url": "https://user.usatoday.com/USAT-GUP/user/logout/", "return_qsp": "return-url"}, "user": {"url": "https://user.usatoday.com/USAT-GUP/user/", "response_user_path": ["response", "user"]}, "personal_link": {"url": "https://login.usatoday.com/USAT-GUP/authenticate/", "qsp": "for-guid", "enabled": true}}, "site_key": "usatoday", "ADS": {"LEAVEBEHIND_EXPIRATION_MINUTES": 60, "THRESHOLDS": {"BIGPAGE_ASSET": [3, 5], "COVERVIEW": 4, "TRANSITION": [2, 5], "TRANSITION_SNAPSHOT": [3, 3], "TRANSITION_INTERACTIVE": [2, 5], "TRANSITION_GALLERY": [3, 4], "TRANSITION_REFERRER": [1, 1]}, "DFP": {"ACCOUNTID": "7103", "CMSID": 12768, "ENV": "prod", "ACCOUNTNAME": "usatoday"}, "teads_enabled": true, "SLIDER": {"REFRESHTIME": 900000, "CLOSETIME": 15000}, "a9": {"url": "http://c.amazon-adsystem.com/aax2/amzn_ads.js", "account": "3062", "enabled": true}, "poster_scroll_refresh_disabled": true, "pubMatic": {"url": "http://ads.pubmatic.com/AdServer/js/gshowad.js", "enabled": true, "account": "57752", "group": "1", "slots": ["ATF@728x90", "BTF@728x90", "ATF@300x250", "BTF@300x250", "ATF@300x600", "ROS@970x250", "ROS@300x1050"]}, "progressive_gallery_refresh_rate": 5, "story_atf_leaderboard": false, "cleanup_selectors": ".prWrap, script[id^=\'prscript\'], #prscrscr, #eyeDiv, body > div[id^=\'adDiv\'], body > div[id^=\'ut_container\']", "high_impact_companion_ad": true, "dfp": {"account_id": "7103", "env": "prod"}, "account_name": "usatoday", "criteo": {"url": "http://rtax.criteo.com/delivery/rta/rta.js", "varName": "crtg_content", "account": "1493", "cookie": "cto_belo", "enabled": true}, "GALLERY": {"SURVEY": true, "REFRESH": true}}, "REFRESH_RATE": 7, "ELECTIONS": {}, "featured_newsletter": {"one_nation": {"fbid": 0}, "shortlist": {"fbid": 0}, "for_the_record": {"fbid": 0}}, "THIRDPARTYAPI": {"FILEMOBILE": {"VHOST": 1056, "SERVICES_ENDPOINT": "https://api.filemobile.com/services/"}, "CXENSE": {"persisted_query_id": "1a966b551c0201fba9829b3fea1b662417ccf3aa", "origin": "gci-web", "insider_site_id": "000", "site_id": "9222363239123726877", "API": "http://api.cxense.com/"}, "CAREERBUILDER": {"lr": {}, "siteid": {}}, "NEON": {"script_url": "http://www.gannett-cdn.com/neon/prod/neonoptimizer_1600036805.js"}, "FACEBOOK": {"PERMISSIONS": "email,user_about_me", "ENABLED": true, "APPID": "215046668549694"}, "Taboola": {"apiBase": "http://api.taboola.com/1.1/json/", "widget": true, "apiKey": "90393b522c6937bd3b1e815ead8d189cea03650", "ENABLED": true, "api_id": "usatodaydemo", "sidebar_widget_mode": "thumbnails-f", "publisher_id": "usatodaydemo"}, "FIREFLY": {"flyoutOverrideArticleViewsRemaining": [], "gps": {"last": "CPPWSUBFIN", "tweener": "CPPWSUB30", "tweener_singular": "CPPWSUB1L", "first": "CPPWFIRST", "custom": "CPPWSUB30"}, "ENABLED": false, "flyoutMessageOverrides": {"last": "This is your last article!", "tweener": " articles left", "tweener_singular": " article left", "first": "Enjoy a limited number of articles over the next 45 days"}}, "GOOGLEPLUS": {"APPPACKAGENAME": "com.usatoday.android.news", "JSLIBURL": "https://apis.google.com/js/client.js", "CLIENTID": "383230156302.apps.googleusercontent.com", "COOKIEPOLICY": "none", "LOGOUT_URL": "https://accounts.google.com/o/oauth2/revoke", "TURNON": true}, "MYCAPTURE": {"SITE_OVERRIDE": null, "PRICING_SHEET_ID": "", "ENAB ...
#   </script>
#   <div class="cXenseParse" style="display:none">
#   </div>
#   <header class=" site-header " data-default-fixed="false" data-default-open="true" data-fixed="true" data-open="true">
#    <div class="site-header-inner-wrap site-header-inner-wrap-fixed ">
#     <div class="site-masthead">
#      <div id="animated-site-logo">
#       <a data-ht="Headeranimatedlogodot" href="/" id="animated-site-logo-dot-link">
#       </a>
#       <a class="animated-site-logo-link" data-ht="Headerusatoday Headeranimatedlogolink" href="/">
#       </a>
#       <img alt="USA Today" src="http://www.gannett-cdn.com/usatoday/editorial/graphics/dynamic-logos/020316-helmet.png" style="position:absolute"/>
#       <script type="text/javascript">
#        \nvar me = document.getElementById(\'animated-site-logo-dot-link\');\nif (me) {\nme.href="http://ftw.usatoday.com/2016/02/the-best-super-bowl-performances-at-every-position";\n}\n
#       </script>
#       <div style="display:none;">
#       </div>
#       <noscript class="MOAT-gannettdigital989586921?moatClientLevel1=12236568&amp;moatClientLevel2=141552648&amp;moatClientLevel3=408220128&amp;moatClientLevel4=102517080648&amp;moatClientSlicer1=12117888&amp;moatClientSlicer2=132776448&amp;zMoatPS=">
#       </noscript>
#       <script src="http://js.moatads.com/gannettdigital989586921/moatad.js#moatClientLevel1=12236568&amp;moatClientLevel2=141552648&amp;moatClientLevel3=408220128&amp;moatClientLevel4=102517080648&amp;moatClientSlicer1=12117888&amp;moatClientSlicer2=132776448&amp;zMoatPS=" type="text/javascript">
#       </script>
#      </div>
#      <div class="site-masthead-search-wrap">
#       <form action="/search/" class="site-masthead-search-form ui-ajax-form" data-mapping="&lt;%= q %&gt;/" method="get">
#        <div class="site-masthead-search-input-wrap ui-form-field-container">
#         <input autocomplete="off" class="site-masthead-search-form-input ui-text-input" data-clearable="true" name="q" placeholder="Search" type="text"/>
#         <div class="site-masthead-search-btn site-masthead-search-btn-div" data-ht="Headersearchbutton">
#         </div>
#        </div>
#        <input class="site-masthead-search-btn submit" type="submit" value="Search"/>
#        <span class="site-masthead-search-close-btn" data-uotrack="Headersearchclosebutton">
#        </span>
#        <div class="site-masthead-subscribe-wrap site-masthead-subscribe-wrap-visible">
#         <a class="userAuth-redirect site-masthead-subscribe-link" data-ht="Headersubscribecallout" href="https://offers.usatoday.com/3FOR34COM?opm_position=masthead&amp;opm_creative=blue-white-text&amp;opm_name=subcribe-for-home-delivery&amp;opm_id=64&amp;keycode=wucag" target="_blank">
#          <span class="site-masthead-subscribe-primary-text">
#           SUBSCRIBE NOW
#          </span>
#          <span class="site-masthead-subscribe-secondary-text">
#           to get home delivery
#          </span>
#         </a>
#        </div>
#        <div class="site-masthead-special-offers-ad partner-placement">
#        </div>
#       </form>
#      </div>
#     </div>
#     <nav class="site-nav">
#      <ul class="site-nav-list">
#       <li class="site-nav-item site-nav-end-item site-nav-logo-item">
#        <a class="site-nav-link site-nav-logo-link" data-ht="Headerlogocollapsed" href="/">
#         <img alt="USA TODAY" class="site-nav-logo-img " height="40" src="http://www.gannett-cdn.com/sites/usatoday/images/site-nav-logo@2x.png"/>
#        </a>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-end-item site-nav-first-primary-item site-nav-text-item site-nav-news-item site-nav-module site-nav-news-module" id="module-position-Ox6ThYMXELE">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-end-link site-nav-first-primary-link site-nav-text-link site-nav-news-link" data-ht="Headernews" href="/news/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-end-span site-nav-first-primary-span site-nav-text-span news-theme-bg-hover usatoday-theme-bg-hover site-nav-news-span">
#           News
#          </span>
#          <span class="site-nav-theme-border news-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-sports-item site-nav-module site-nav-sports-module" id="module-position-Ox6ThYNBjmY">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-sports-link" data-ht="Headersports" href="/sports/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span sports-theme-bg-hover usatoday-theme-bg-hover site-nav-sports-span">
#           Sports
#          </span>
#          <span class="site-nav-theme-border sports-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-life-item site-nav-module site-nav-life-module" id="module-position-Ox6ThYPFLBI">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-life-link" data-ht="Headerlife" href="/life/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span life-theme-bg-hover usatoday-theme-bg-hover site-nav-life-span">
#           Life
#          </span>
#          <span class="site-nav-theme-border life-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-money-item site-nav-module site-nav-money-module" id="module-position-Ox6ThYP5F8s">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-money-link" data-ht="Headermoney" href="/money/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span money-theme-bg-hover usatoday-theme-bg-hover site-nav-money-span">
#           Money
#          </span>
#          <span class="site-nav-theme-border money-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-tech-item site-nav-module site-nav-tech-module" id="module-position-Ox6ThYOxndk">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-tech-link" data-ht="Headertech" href="/tech/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span tech-theme-bg-hover usatoday-theme-bg-hover site-nav-tech-span">
#           Tech
#          </span>
#          <span class="site-nav-theme-border tech-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-travel-item site-nav-module site-nav-travel-module" id="module-position-Ox6ThYQOV9Q">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-travel-link" data-ht="Headertravel" href="/travel/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span travel-theme-bg-hover usatoday-theme-bg-hover site-nav-travel-span">
#           Travel
#          </span>
#          <span class="site-nav-theme-border travel-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-opinion-item site-nav-module site-nav-opinion-module" id="module-position-Ox6ThYQ_Yao">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-opinion-link" data-ht="Headeropinion" href="/opinion/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span opinion-theme-bg-hover usatoday-theme-bg-hover site-nav-opinion-span">
#           Opinion
#          </span>
#          <span class="site-nav-theme-border opinion-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-weather-item site-nav-module site-nav-weather-module" id="module-position-Ox6ThYQf6Z4">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-text-link site-nav-weather-link" data-ht="Headerweather" href="/weather/">
#          <div class="site-nav-span-wrap site-nav-text-span-wrap">
#           <span class="site-nav-span site-nav-text-span site-nav-alt-span site-nav-weather-span wbtn-wrap-wicon" data-weather="temperature" data-weather-suffix="°">
#           </span>
#           <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span weather-theme-bg-hover usatoday-theme-bg-hover site-nav-weather-span">
#            Weather
#           </span>
#          </div>
#          <span class="site-nav-theme-border weather-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#         <div class="weather-nav-dropdown">
#          <div class="weather-nav-dropdown-panel-wrap">
#           <div class="weather-nav-conditions-panel">
#            <p class="weather-nav-location-name">
#            </p>
#            <div class="weather-nav-dropdown-time" data-weather="observationTime">
#            </div>
#            <div class="weather-nav-dropdown-wicon">
#             Icon
#            </div>
#            <div class="weather-nav-dropdown-temp" data-weather="temperature" data-weather-suffix="°">
#            </div>
#            <ul class="weather-nav-conditions-wrap">
#             <li class="weather-nav-condition-humidity">
#              <span class="weather-nav-condition-title">
#               Humidity
#              </span>
#              <span class="weather-nav-condition-value" data-weather="humidity" data-weather-suffix=" ">
#              </span>
#             </li>
#             <li class="weather-nav-condition-precip">
#              <span class="weather-nav-condition-title">
#               Precip.
#              </span>
#              <span class="weather-nav-condition-value" data-weather="precip" data-weather-suffix=" in">
#              </span>
#             </li>
#             <li class="weather-nav-condition-wind">
#              <span class="weather-nav-condition-title">
#               Winds
#              </span>
#              <span class="weather-nav-condition-value" data-weather="windSpeed" data-weather-suffix=" mph">
#              </span>
#             </li>
#            </ul>
#            <div class="weather-nav-dropdown-settings-open-btn">
#             Open settings
#            </div>
#           </div>
#           <div class="weather-nav-settings-panel">
#            <p class="weather-nav-settings-header">
#             Settings
#            </p>
#            <form class="weather-nav-location-form" method="get">
#             <label class="weather-nav-location-input-label">
#              Enter City, State or Zip
#             </label>
#             <div class="ui-form-field-container weather-nav-location-input-wrap">
#              <input class="ui-text-input weather-nav-location-input" data-autocomplete-url="/weather/cities/v2/search.json?q=&lt;%=encodeURIComponent(query)%&gt;" data-clearable="true" type="text" value=""/>
#              <div class="weather-nav-location-error">
#              </div>
#             </div>
#             <p class="ui-btn header-nav-dropdown-dark-btn weather-nav-location-cancel-btn">
#              Cancel
#             </p>
#             <p class="ui-btn header-nav-dropdown-light-btn weather-nav-location-set-btn">
#              Set
#             </p>
#            </form>
#            <div class="weather-nav-dropdown-settings-close-btn">
#             Close settings
#            </div>
#           </div>
#          </div>
#          <a class="weather-nav-full-forecast-btn" href="/weather/">
#           Full Forecast
#          </a>
#         </div>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-crosswords-item site-nav-module site-nav-crosswords-module" id="module-position-Ox6ThYTpo2A">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-auxiliary-text-link site-nav-auxiliary-text-link site-nav-crosswords-link" data-ht="Headercrosswords" href="http://crosswords.usatoday.com/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-crosswords-span">
#           Crosswords
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-elections-2016-item site-nav-module site-nav-elections-2016-module" id="module-position-Ox6ThYT1_CU">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-text-link site-nav-text-link site-nav-elections-2016-link" data-ht="Headerelections-2016" href="http://www.usatoday.com/section/global/elections-2016/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span elections-2016-theme-bg-hover usatoday-theme-bg-hover site-nav-elections-2016-span">
#           Elections 2016
#          </span>
#          <span class="site-nav-theme-border elections-2016-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-investigations-item site-nav-module site-nav-investigations-module" id="module-position-Ox6ThYULXtk">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-investigations-link" data-ht="Headerinvestigations" href="/topic/f4cd5d76-8c46-4d69-8a8f-85dfd6fefc5c/investigations/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-investigations-span">
#           Investigations
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-text-item site-nav-admeter-item site-nav-module site-nav-admeter-module" id="module-position-Ox6ThYUVeec">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-text-link site-nav-text-link site-nav-admeter-link" data-ht="Headeradmeter" href="http://admeter.usatoday.com/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-text-span admeter-theme-bg-hover usatoday-theme-bg-hover site-nav-admeter-span">
#           AD Meter
#          </span>
#          <span class="site-nav-theme-border admeter-theme-bg usatoday-theme-bg">
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-video-item site-nav-module site-nav-video-module" id="module-position-Ox6ThYU67Ts">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-video-link" data-ht="Headervideo" href="/media/latest/videos/news/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-video-span">
#           Video
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-stocks-item site-nav-module site-nav-stocks-module" id="module-position-Ox6ThYVZJ8U">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-stocks-link" data-ht="Headerstocks" href="/money/markets/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-stocks-span">
#           Stocks
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-apps-item site-nav-module site-nav-apps-module" id="module-position-Ox6ThYWTqAo">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-auxiliary-text-link site-nav-auxiliary-text-link site-nav-apps-link" data-ht="Headerapps" href="http://static.usatoday.com/mobile-apps/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-apps-span">
#           Apps
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-bestsellingbooks-item site-nav-module site-nav-bestsellingbooks-module" id="module-position-Ox6ThYW5DS4">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-bestsellingbooks-link" data-ht="Headerbestsellingbooks" href="/life/books/best-selling/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-bestsellingbooks-span">
#           Best-Selling Books
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-classifieds-item site-nav-module site-nav-classifieds-module" id="module-position-Ox6ThYpRg2w">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-auxiliary-text-link site-nav-auxiliary-text-link site-nav-classifieds-link" data-ht="Headerclassifieds" href="http://www.usatodayclassifieds.com/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-classifieds-span">
#           Classifieds
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-college-item site-nav-module site-nav-college-module" id="module-position-Ox6ThYrErzg">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-auxiliary-text-link site-nav-auxiliary-text-link site-nav-college-link" data-ht="Headercollege" href="http://college.usatoday.com/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-college-span">
#           College
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-corrections-item site-nav-module site-nav-corrections-module" id="module-position-Ox6ThYt4gdQ">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-corrections-link" data-ht="Headercorrections" href="/story/news/2013/01/09/corrections-clarifications/1821023/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-corrections-span">
#           Corrections
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-interactives-item site-nav-module site-nav-interactives-module" id="module-position-Ox6ThYsh7tE">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-interactives-link" data-ht="Headerinteractives" href="/topic/E01C4890-85A2-4E0B-A3DD-58BD88E71251/interactive-graphics/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-interactives-span">
#           Interactives
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-newsletters-item site-nav-module site-nav-newsletters-module" id="module-position-Ox6ThYsLPlU">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-auxiliary-text-link site-nav-auxiliary-text-link site-nav-newsletters-link" data-ht="Headernewsletters" href="https://account.usatoday.com/newsletters/" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-newsletters-span">
#           Newsletters
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-photo-galleries-item site-nav-module site-nav-photo-galleries-module" id="module-position-Ox6ThYztGcs">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-photo-galleries-link" data-ht="Headerphoto-galleries" href="/media/latest/photos/news/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-photo-galleries-span">
#           Photo Galleries
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-portfoliotracker-item site-nav-module site-nav-portfoliotracker-module" id="module-position-Ox6ThY5WFCo">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-external-auxiliary-text-link site-nav-auxiliary-text-link site-nav-portfoliotracker-link" data-ht="Headerportfoliotracker" href="https://portfoliotracker.usatoday.com/portfolio" target="_blank">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-portfoliotracker-span">
#           Portfolio Tracker
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-scores-item site-nav-module site-nav-scores-module" id="module-position-Ox6ThZHwdvU">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-scores-link" data-ht="Headerscores" href="/sports/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-scores-span">
#           Scores
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-auxiliary-text-item site-nav-newsstand-item site-nav-module site-nav-newsstand-module" id="module-position-Ox6ThZzE9xo">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-auxiliary-text-link site-nav-newsstand-link" data-ht="Headernewsstand" href="/shop/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-auxiliary-text-span site-nav-newsstand-span">
#           Newsstand
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-end-item site-nav-last-primary-item site-nav-auxiliary-text-item site-nav-audio-item site-nav-module site-nav-audio-module" id="module-position-Ox6ThZzFXf0">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-end-link site-nav-last-primary-link site-nav-auxiliary-text-link site-nav-audio-link" data-ht="Headeraudio" href="/pages/interactives/podcast-player/">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-end-span site-nav-last-primary-span site-nav-auxiliary-text-span site-nav-audio-span">
#           Audio
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-more-item site-nav-text-item site-nav-module site-nav-text-module" id="module-position-">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-more-link site-nav-text-link" data-ht="Headertext" href="">
#          <div class="site-nav-span-wrap site-nav-more-span-wrap">
#           <span class="site-nav-span site-nav-span-theme-usatoday site-nav-more-span site-nav-text-span">
#            More
#           </span>
#          </div>
#         </a>
#         <div class="site-nav-dropdown site-nav-more-dropdown site-nav-more-dropdown-1col">
#          <div class="site-nav-dropdown-inner-wrap site-nav-more-dropdown-inner-wrap">
#           <ul class="site-nav-more-dropdown-list site-nav-more-dropdown-list-1col">
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorenews" href="/news/">
#              News
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoresports" href="/sports/">
#              Sports
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorelife" href="/life/">
#              Life
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoremoney" href="/money/">
#              Money
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoretech" href="/tech/">
#              Tech
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoretravel" href="/travel/">
#              Travel
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreopinion" href="/opinion/">
#              Opinion
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreweather" href="/weather/">
#              Weather
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorecrosswords" href="http://crosswords.usatoday.com/">
#              Crosswords
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreelections-2016" href="http://www.usatoday.com/section/global/elections-2016/">
#              Elections 2016
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreinvestigations" href="/topic/f4cd5d76-8c46-4d69-8a8f-85dfd6fefc5c/investigations/">
#              Investigations
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreadmeter" href="http://admeter.usatoday.com/">
#              AD Meter
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorevideo" href="/media/latest/videos/news/">
#              Video
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorestocks" href="/money/markets/">
#              Stocks
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreapps" href="http://static.usatoday.com/mobile-apps/">
#              Apps
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorebestsellingbooks" href="/life/books/best-selling/">
#              Best-Selling Books
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreclassifieds" href="http://www.usatodayclassifieds.com/">
#              Classifieds
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorecollege" href="http://college.usatoday.com/">
#              College
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorecorrections" href="/story/news/2013/01/09/corrections-clarifications/1821023/">
#              Corrections
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreinteractives" href="/topic/E01C4890-85A2-4E0B-A3DD-58BD88E71251/interactive-graphics/">
#              Interactives
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorenewsletters" href="https://account.usatoday.com/newsletters/">
#              Newsletters
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorephoto-galleries" href="/media/latest/photos/news/">
#              Photo Galleries
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreportfoliotracker" href="https://portfoliotracker.usatoday.com/portfolio">
#              Portfolio Tracker
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorescores" href="/sports/">
#              Scores
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermorenewsstand" href="/shop/">
#              Newsstand
#             </a>
#            </li>
#            <li class="site-nav-more-dropdown-item site-nav-more-dropdown-item-1col">
#             <a class="site-nav-more-dropdown-link" data-ht="Headermoreaudio" href="/pages/interactives/podcast-player/">
#              Audio
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-primary-item site-nav-spacer-item site-nav-spacer-item site-nav-module site-nav-spacer-module" id="module-position-">
#        <span class="site-nav-inner-wrap">
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-secondary-item site-nav-end-item site-nav-first-secondary-item site-nav-icon-item site-nav-search-item site-nav-module site-nav-search-module" id="module-position-Ox6ThaCYVbw">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-end-link site-nav-first-secondary-link site-nav-icon-link site-nav-search-link" data-ht="Headersearch" href="/search">
#          <span class="site-nav-span site-nav-span-theme-usatoday site-nav-end-span site-nav-first-secondary-span site-nav-icon-span site-nav-search-span">
#           Search
#          </span>
#         </a>
#        </span>
#       </li>
#       <li class="site-nav-item site-nav-item-theme-usatoday site-nav-secondary-item site-nav-end-item site-nav-last-secondary-item site-nav-icon-item site-nav-firefly-item site-nav-module site-nav-firefly-module" id="module-position-Ox6ThaAnElg">
#        <span class="site-nav-inner-wrap">
#         <a class=" site-nav-link site-nav-link-theme-usatoday site-nav-end-link site-nav-last-secondary-link site-nav-icon-link site-nav-firefly-link" data-ht="Headerfirefly" href="/">
#          <div class="site-nav-span-wrap site-nav-icon-span-wrap">
#           <span class="site-nav-span site-nav-span-theme-usatoday site-nav-end-span site-nav-last-secondary-span site-nav-icon-span site-nav-firefly-span">
#            Firefly
#           </span>
#          </div>
#         </a>
#         <div class="site-nav-dropdown site-nav-firefly-dropdown">
#          <div class="site-nav-firefly-dropdown-section ff-greetings">
#           <p class="site-nav-firefly-dropdown-text">
#            Hi
#            <span class="site-nav-firefly-user-display-name">
#            </span>
#           </p>
#          </div>
#          <div class="site-nav-firefly-dropdown-section ff-login">
#           <p class="site-nav-firefly-dropdown-text">
#            Already a subscriber?
#           </p>
#           <a class="ui-chunky-btn secondary ff ff-login-btn firefly-signin-btn userAuth-redirect" data-ht="HeaderUserAuthLogin" data-user-account="firefly" href="https://login.usatoday.com/USAT-GUP/authenticate/?success-url=http%3A//www.usatoday.com/search/donald%2520trump/&amp;cancel-url=http%3A//www.usatoday.com/search/donald%2520trump/">
#            Sign In
#           </a>
#          </div>
#          <div class="site-nav-firefly-dropdown-section ff-subscribe">
#           <p class="site-nav-firefly-dropdown-text">
#            Subscribe today to additional USAToday products.
#           </p>
#           <a class="ui-chunky-btn ff subscribe-btn firefly-subscribe-btn userAuth-redirect" href="https://service.usatoday.com/products.html">
#            Subscribe Now
#           </a>
#          </div>
#          <div class="site-nav-firefly-dropdown-section ff-activate">
#           <p class="site-nav-firefly-dropdown-text">
#            Already a print edition subscriber, but don\'t have a login?
#           </p>
#           <a class="ff activate-btn firefly-activate-btn userAuth-redirect" data-user-account="firefly" href="https://service.usatoday.com/firsttime/first_time.jsp">
#            Activate your digital access.
#           </a>
#          </div>
#          <div class="site-nav-firefly-dropdown-section ff-account">
#           <p class="site-nav-firefly-dropdown-text">
#            Manage your account settings.
#           </p>
#           <a class="ui-chunky-btn ff subscribe-btn firefly-subscribe-btn" data-user-account="firefly" href="https://service.usatoday.com/login/auth.faces">
#            My Account
#           </a>
#          </div>
#          <div class="site-nav-firefly-dropdown-section ff-logout">
#           <p class="site-nav-firefly-dropdown-text">
#            <a class="ff-logout-btn userAuth-redirect" data-ht="HeaderUserAuthLogout" href="https://user.usatoday.com/USAT-GUP/user/logout/?return-url=http%3A//www.usatoday.com/search/donald%2520trump/">
#             Log Out
#            </a>
#           </p>
#          </div>
#         </div>
#        </span>
#       </li>
#      </ul>
#     </nav>
#     <div class="bnm-container">
#     </div>
#    </div>
#    <script class="headermodules headermodules-primary" type="json/headermodules">
# ...
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Donald Trump says Ted Cruz 'stole' Iowa
#           </h3>
#           <p class="text">
#            Suffice it to say, he's not so congratulatory anymore.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Donald Trump says Ted Cruz 'stole' Iowa
#           </h3>
#           <p class="text">
#            Suffice it to say, he's not so congratulatory anymore.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             Cooper Allen, USA TODAY
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="video recommended search-result-item">
#         <span class="parent-label news">
#          Elections  2016
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_video_3" href="/videos/news/politics/elections/2016/2016/02/03/79764276/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <div class="search-video">
#             <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/9ceb1642bad5fcd0dafe5371759bae7746a517df/r=x118&amp;c=200x115/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4736978855001_4736962853001-vs.jpg"/>
#            </div>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Donald Trump addresses Iowa results at New Hampshire rally
#           </h3>
#           <p class="text">
#            Listen to Donald Trump attack Ted Cruz's antics during the Iowa Caucus at a speech in New Hampshire.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Donald Trump addresses Iowa results at New Hampshire rally
#           </h3>
#           <p class="text">
#            Listen to Donald Trump attack Ted Cruz's antics during the Iowa Caucus at a speech in New Hampshire.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             USA TODAY
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="text search-result-item">
#         <span class="parent-label news">
#          Elections  2016
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_text_4" href="/story/news/politics/elections/2016/2016/02/03/meet-people-who-give-money-billionaire/79710764/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/b4bcac9e54b6233210e62c73d63b54d0c6a04501/c=0-137-4530-2696&amp;r=x118&amp;c=200x115/local/-/media/2016/02/03/USATODAY/USATODAY/635900966233932470-AP-GOP-2016-Trump-014.jpg"/>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Meet the people who give campaign money to billionaire Donald Trump
#           </h3>
#           <p class="text">
#            Sometimes they just want the baseball cap.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Meet the people who give campaign money to billionaire Donald Trump
#           </h3>
#           <p class="text">
#            Sometimes they just want the baseball cap.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             Ledyard King and Fredreka Schouten, USA TODAY
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="text search-result-item">
#         <span class="parent-label money">
#          Rieder
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_text_5" href="/story/money/columnist/rieder/2016/02/03/rieder-what-next-trump-media-circus/79751140/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/ab8bfaf86dbd23bbd9ee2465887bbcae3704b61c/c=0-32-3000-1727&amp;r=x118&amp;c=200x115/local/-/media/2016/02/03/USATODAY/USATODAY/635901070728327746-GTY-508077238.jpg"/>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Rieder: What next for Trump media circus?
#           </h3>
#           <p class="text">
#            Trump's Iowa setback may dent his domination of the campaign.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Rieder: What next for Trump media circus?
#           </h3>
#           <p class="text">
#            Trump's Iowa setback may dent his domination of the campaign.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             Rem Rieder, USA TODAY
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="text search-result-item">
#         <span class="parent-label money">
#          Rieder
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_text_6" href="/story/money/columnist/rieder/2016/01/27/rieder-trump-meets-his-match-kelly/79400776/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/8247faa231ed0fbd141e2c4700ac4072aa94efb8/c=0-138-2996-1831&amp;r=x118&amp;c=200x115/local/-/media/2016/01/27/USATODAY/USATODAY/635895012748211940-axx-kelly-28.jpg"/>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Rieder: Trump meets his match in Kelly
#           </h3>
#           <p class="text">
#            Tough-talking Trump backs away from another go-round with Fox News' Megyn Kelly.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Rieder: Trump meets his match in Kelly
#           </h3>
#           <p class="text">
#            Tough-talking Trump backs away from another go-round with Fox News' Megyn Kelly.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             Rem Rieder, USA TODAY
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="text search-result-item">
#         <span class="parent-label news">
#          Elections
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_text_7" href="/story/news/politics/elections/2016/01/30/iowa-poll-des-moines-register-bloomberg-republicans-cruz-trump/79514706/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/0bda2f65efb57b6118649a6d6d9bd4b909b7509c/c=0-196-3863-2378&amp;r=x118&amp;c=200x115/local/-/media/2016/01/29/USATODAY/USATODAY/635896631524689326-AP-GOP-2016-Trump.jpg"/>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Trump regains lead in final Iowa Poll before caucuses
#           </h3>
#           <p class="text">
#            Donald Trump has muscled ahead in Iowa,\xc2\xa0regaining\xc2\xa0his lead on the brink\xc2\xa0of the first votes being cast in the 2016 presidential race.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Trump regains lead in final Iowa Poll before caucuses
#           </h3>
#           <p class="text">
#            Donald Trump has muscled ahead in Iowa,\xc2\xa0regaining\xc2\xa0his lead on the brink\xc2\xa0of the first votes being cast in the 2016 presidential race.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             Jennifer Jacobs, The Des Moines Register
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="text search-result-item">
#         <span class="parent-label news">
#          OnPolitics
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_text_8" href="/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/c8d6c2696a535bde74d1cf49ab08cf93c4d2271f/c=0-125-3802-2273&amp;r=x118&amp;c=200x115/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 3, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Trump: New Hampshire 'probably suits me better'
#           </h3>
#           <p class="text">
#            Finishing second? It's not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Trump: New Hampshire 'probably suits me better'
#           </h3>
#           <p class="text">
#            Finishing second? It's not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             Susan Page, USA TODAY
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="video search-result-item">
#         <span class="parent-label news">
#          Elections  2016
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_video_9" href="/videos/news/politics/elections/2016/2016/02/02/79730384/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <div class="search-video">
#             <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/9ceb1642bad5fcd0dafe5371759bae7746a517df/r=x118&amp;c=200x115/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4735367406001_video-still-for-video-4735263107001.jpg"/>
#            </div>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 2, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            A very toned down Donald Trump explains his Iowa loss
#           </h3>
#           <p class="text">
#            After enduring more than six months of chest-thumping bravado, Americans are finally learning what brings Donald Trump back down to earth, losing. Trump placed second Monday night in Iowa to Sen. Ted Cruz.
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            A very toned down Donald Trump explains his Iowa loss
#           </h3>
#           <p class="text">
#            After enduring more than six months of chest-thumping bravado, Americans are finally learning what brings Donald Trump back down to earth, losing. Trump placed second Monday night in Iowa to Sen. Ted Cruz.
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             USA TODAY, Wochit
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="video search-result-item">
#         <span class="parent-label news">
#          Elections  2016
#         </span>
#         <a class="search-result-item-link" data-ht="search_results_video_10" href="/videos/news/politics/elections/2016/2016/02/02/79732372/">
#          <div class="front">
#           <figure class="search-result-figure">
#            <div class="search-video">
#             <img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/9ceb1642bad5fcd0dafe5371759bae7746a517df/r=x118&amp;c=200x115/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4735366763001_thumb-2a3971d628855b068f0f6a70670055a3.jpg"/>
#            </div>
#           </figure>
#           <p class="meta">
#            <span class="date-created meta-info-text">
#             Feb 2, 2016
#            </span>
#           </p>
#           <h3 class="search-result-title search-results-headline">
#            Trump 'not humiliated' by Iowa result
#           </h3>
#           <p class="text">
#            Republican presidential candidate Donald Trump on Tuesday said he was "not humiliated" by his second-place finish in his party's Iowa caucus. He also played down the achievement of his rival Marco Rubio, who finished in a close third place. (Feb. 2)
#           </p>
#           <div class="clearleft">
#           </div>
#          </div>
#          <div class="back">
#           <h3 class="search-result-title-back search-results-headline">
#            Trump 'not humiliated' by Iowa result
#           </h3>
#           <p class="text">
#            Republican presidential candidate Donald Trump on Tuesday said he was "not humiliated" by his second-place finish in his party's Iowa caucus. He also played down the achievement of his rival Marco Rubio, who finished in a close third place. (Feb. 2)
#           </p>
#           <p class="meta">
#            <span class="attribution meta-info-text">
#             AP, AP
#            </span>
#           </p>
#          </div>
#         </a>
#        </li>
#        <li class="search-result-item more-results" data-href="/search/donald trump/2/">
#        </li>
#       </ul>
#      </div>
#      <!-- list-content END! -->
#     </div>
#     <!-- inner END! -->
#     <div class="browser-shadow">
#     </div>
#     <!-- comscorekw=bugpages -->
#     <script class="pageinfo" type="json/pageinfo">
#      \n{"contenttype": "search-front", "pathName": "/search", "cst": "search", "headline": "Search Results for \\"donald trump\\"", "ssts": "search", "searchkeywords": "donald trump", "texttype": "search-results", "basePageType": "search"}\n
#     </script>
#    </div>
#   </div>
#   <div id="ad-staging">
#   </div>
#   <script src="//www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <!--[if lt IE 9]><script type="text/javascript" src="http://www.gannett-cdn.com/static/usat-web-static-1842.0/jsb/main_legacy.min.js"></script><![endif]-->
#   <!--[if gt IE 8]><!-->
#   <script src="http://www.gannett-cdn.com/static/usat-web-static-1842.0/jsb/main.min.js" type="text/javascript">
#   </script>
#   <!--<![endif]-->
#   <div id="fb-root">
#   </div>
#   \n'
#  </body>
# </html>

# %%
tag_set = soup.find_all('a', class_='search-result-item-link')
tag_set
# Out:
# [<a class="search-result-item-link" data-ht="search_results_video-playlist_1" href="/videos/news/politics/elections/2016/2016/02/03/donald-trump-on-the-campaign-trail/71659642/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/dc6bab708a212ecd9f3b6aca35c50697de6bd32a/r=x328&amp;c=440x325/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4736978855001_4736962853001-vs.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Donald Trump on the campaign trail</h3><p class="text">Donald Trump on the campaign trail</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Donald Trump on the campaign trail</h3><p class="text">Donald Trump on the campaign trail</p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_text_2" href="/story/news/politics/onpolitics/2016/02/03/donald-trump-ted-cruz-iowa-caucuses/79748926/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/d1936c2ed87ca43372a234e577b6fd9973521ef7/c=0-231-4545-2799&amp;r=x118&amp;c=200x115/local/-/media/2016/02/03/USATODAY/USATODAY/635900913199306400-AP-GOP-2016-Trump.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Donald Trump says Ted Cruz 'stole' Iowa</h3><p class="text">Suffice it to say, he's not so congratulatory anymore.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Donald Trump says Ted Cruz 'stole' Iowa</h3><p class="text">Suffice it to say, he's not so congratulatory anymore.</p><p class="meta"><span class="attribution meta-info-text">Cooper Allen, USA TODAY</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_video_3" href="/videos/news/politics/elections/2016/2016/02/03/79764276/"><div class="front"><figure class="search-result-figure"><div class="search-video"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/9ceb1642bad5fcd0dafe5371759bae7746a517df/r=x118&amp;c=200x115/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4736978855001_4736962853001-vs.jpg"/></div></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Donald Trump addresses Iowa results at New Hampshire rally</h3><p class="text">Listen to Donald Trump attack Ted Cruz's antics during the Iowa Caucus at a speech in New Hampshire.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Donald Trump addresses Iowa results at New Hampshire rally</h3><p class="text">Listen to Donald Trump attack Ted Cruz's antics during the Iowa Caucus at a speech in New Hampshire.</p><p class="meta"><span class="attribution meta-info-text">USA TODAY</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_text_4" href="/story/news/politics/elections/2016/2016/02/03/meet-people-who-give-money-billionaire/79710764/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/b4bcac9e54b6233210e62c73d63b54d0c6a04501/c=0-137-4530-2696&amp;r=x118&amp;c=200x115/local/-/media/2016/02/03/USATODAY/USATODAY/635900966233932470-AP-GOP-2016-Trump-014.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Meet the people who give campaign money to billionaire Donald Trump</h3><p class="text">Sometimes they just want the baseball cap.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Meet the people who give campaign money to billionaire Donald Trump</h3><p class="text">Sometimes they just want the baseball cap.</p><p class="meta"><span class="attribution meta-info-text">Ledyard King and Fredreka Schouten, USA TODAY</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_text_5" href="/story/money/columnist/rieder/2016/02/03/rieder-what-next-trump-media-circus/79751140/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/ab8bfaf86dbd23bbd9ee2465887bbcae3704b61c/c=0-32-3000-1727&amp;r=x118&amp;c=200x115/local/-/media/2016/02/03/USATODAY/USATODAY/635901070728327746-GTY-508077238.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Rieder: What next for Trump media circus?</h3><p class="text">Trump's Iowa setback may dent his domination of the campaign.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Rieder: What next for Trump media circus?</h3><p class="text">Trump's Iowa setback may dent his domination of the campaign.</p><p class="meta"><span class="attribution meta-info-text">Rem Rieder, USA TODAY</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_text_6" href="/story/money/columnist/rieder/2016/01/27/rieder-trump-meets-his-match-kelly/79400776/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/8247faa231ed0fbd141e2c4700ac4072aa94efb8/c=0-138-2996-1831&amp;r=x118&amp;c=200x115/local/-/media/2016/01/27/USATODAY/USATODAY/635895012748211940-axx-kelly-28.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Rieder: Trump meets his match in Kelly</h3><p class="text">Tough-talking Trump backs away from another go-round with Fox News' Megyn Kelly.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Rieder: Trump meets his match in Kelly</h3><p class="text">Tough-talking Trump backs away from another go-round with Fox News' Megyn Kelly.</p><p class="meta"><span class="attribution meta-info-text">Rem Rieder, USA TODAY</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_text_7" href="/story/news/politics/elections/2016/01/30/iowa-poll-des-moines-register-bloomberg-republicans-cruz-trump/79514706/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/0bda2f65efb57b6118649a6d6d9bd4b909b7509c/c=0-196-3863-2378&amp;r=x118&amp;c=200x115/local/-/media/2016/01/29/USATODAY/USATODAY/635896631524689326-AP-GOP-2016-Trump.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Trump regains lead in final Iowa Poll before caucuses</h3><p class="text">Donald Trump has muscled ahead in Iowa,\xc2\xa0regaining\xc2\xa0his lead on the brink\xc2\xa0of the first votes being cast in the 2016 presidential race.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Trump regains lead in final Iowa Poll before caucuses</h3><p class="text">Donald Trump has muscled ahead in Iowa,\xc2\xa0regaining\xc2\xa0his lead on the brink\xc2\xa0of the first votes being cast in the 2016 presidential race.</p><p class="meta"><span class="attribution meta-info-text">Jennifer Jacobs, The Des Moines Register</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_text_8" href="/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/"><div class="front"><figure class="search-result-figure"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/c8d6c2696a535bde74d1cf49ab08cf93c4d2271f/c=0-125-3802-2273&amp;r=x118&amp;c=200x115/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/></figure><p class="meta"><span class="date-created meta-info-text">Feb 3, 2016</span></p><h3 class="search-result-title search-results-headline">Trump: New Hampshire 'probably suits me better'</h3><p class="text">Finishing second? It's not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Trump: New Hampshire 'probably suits me better'</h3><p class="text">Finishing second? It's not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses.</p><p class="meta"><span class="attribution meta-info-text">Susan Page, USA TODAY</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_video_9" href="/videos/news/politics/elections/2016/2016/02/02/79730384/"><div class="front"><figure class="search-result-figure"><div class="search-video"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/9ceb1642bad5fcd0dafe5371759bae7746a517df/r=x118&amp;c=200x115/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4735367406001_video-still-for-video-4735263107001.jpg"/></div></figure><p class="meta"><span class="date-created meta-info-text">Feb 2, 2016</span></p><h3 class="search-result-title search-results-headline">A very toned down Donald Trump explains his Iowa loss</h3><p class="text">After enduring more than six months of chest-thumping bravado, Americans are finally learning what brings Donald Trump back down to earth, losing. Trump placed second Monday night in Iowa to Sen. Ted Cruz.</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">A very toned down Donald Trump explains his Iowa loss</h3><p class="text">After enduring more than six months of chest-thumping bravado, Americans are finally learning what brings Donald Trump back down to earth, losing. Trump placed second Monday night in Iowa to Sen. Ted Cruz.</p><p class="meta"><span class="attribution meta-info-text">USA TODAY, Wochit</span></p></div></a>,
#  <a class="search-result-item-link" data-ht="search_results_video_10" href="/videos/news/politics/elections/2016/2016/02/02/79732372/"><div class="front"><figure class="search-result-figure"><div class="search-video"><img class="search-result-image" src="http://www.gannett-cdn.com/-mm-/9ceb1642bad5fcd0dafe5371759bae7746a517df/r=x118&amp;c=200x115/http/videos.usatoday.net/Brightcove2/29906170001/2016/02/29906170001_4735366763001_thumb-2a3971d628855b068f0f6a70670055a3.jpg"/></div></figure><p class="meta"><span class="date-created meta-info-text">Feb 2, 2016</span></p><h3 class="search-result-title search-results-headline">Trump 'not humiliated' by Iowa result</h3><p class="text">Republican presidential candidate Donald Trump on Tuesday said he was "not humiliated" by his second-place finish in his party's Iowa caucus. He also played down the achievement of his rival Marco Rubio, who finished in a close third place. (Feb. 2)</p><div class="clearleft"></div></div><div class="back"><h3 class="search-result-title-back search-results-headline">Trump 'not humiliated' by Iowa result</h3><p class="text">Republican presidential candidate Donald Trump on Tuesday said he was "not humiliated" by his second-place finish in his party's Iowa caucus. He also played down the achievement of his rival Marco Rubio, who finished in a close third place. (Feb. 2)</p><p class="meta"><span class="attribution meta-info-text">AP, AP</span></p></div></a>]

# %%
tag_set[0].get('href')
# Out:
# '/videos/news/politics/elections/2016/2016/02/03/donald-trump-on-the-campaign-trail/71659642/'

# %%
articles = get_articles(results_html, n=5)
articles[0]
# Out:
# Retrieving from cache: http://www.usatoday.com/story/news/politics/onpolitics/2016/02/03/donald-trump-ted-cruz-iowa-caucuses/79748926/
# Retrieving from cache: http://www.usatoday.com/story/news/politics/elections/2016/2016/02/03/meet-people-who-give-money-billionaire/79710764/
# Retrieving from cache: http://www.usatoday.com/story/money/columnist/rieder/2016/02/03/rieder-what-next-trump-media-circus/79751140/
# Retrieving from cache: http://www.usatoday.com/story/money/columnist/rieder/2016/01/27/rieder-trump-meets-his-match-kelly/79400776/
# Retrieving from cache: http://www.usatoday.com/story/news/politics/elections/2016/01/30/iowa-poll-des-moines-register-bloomberg-republicans-cruz-trump/79514706/
# 'b\'<!doctype html><!--[if IE 8]><html class="no-js lt-ie10 lt-ie9" lang="en"><![endif]--><!--[if IE 9]><html class="no-js lt-ie10" lang="en"><![endif]--><!--[if gt IE 10]><!--><html class="no-js" lang="en"  itemscope itemtype="http://schema.org/NewsArticle" ><!--<![endif]--><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><title>Donald Trump says Ted Cruz \\\'stole\\\' Iowa</title><meta content="text/html; charset=UTF-8" name="Content-Type" /><meta name="google" content="notranslate"><meta name="description" itemprop="description" content="Suffice it to say, he&#39;s not so congratulatory anymore."><link rel="canonical" href="http://www.usatoday.com/story/news/politics/onpolitics/2016/02/03/donald-trump-ted-cruz-iowa-caucuses/79748926/"><meta property="fb:app_id" content="215046668549694"/><meta property="og:site_name" content="USA TODAY" /><meta name="ROBOTS" content="NOODP, NOYDIR" /><meta property="og:image" content="http://www.gannett-cdn.com/-mm-/4ba952a39bfa318478a9754c1c95d9a79eca458c/c=0-231-4545-2799&amp;r=x633&amp;c=1600x630/local/-/media/2016/02/03/USATODAY/USATODAY/635900913199306400-AP-GOP-2016-Trump.jpg"/><meta property="og:image:width" content="1600" /><meta property="og:image:height" content="630" /><meta itemprop="thumbnailUrl" content="http://www.gannett-cdn.com/-mm-/c408c53064869a36dc0b19652f565229837e1a94/c=863-0-3893-3030&amp;r=x153&amp;c=150x150/local/-/media/2016/02/03/USATODAY/USATODAY/635900913199306400-AP-GOP-2016-Trump.jpg"/><meta itemprop="thumbnailHeight" content="150"/><meta itemprop="thumbnailWidth" content="150"/><meta itemprop="image" content="http://www.gannett-cdn.com/-mm-/556c46c070928748e6c3681cffa5176c8c443088/c=863-0-3893-3030&amp;r=x203&amp;c=200x200/local/-/media/2016/02/03/USATODAY/USATODAY/635900913199306400-AP-GOP-2016-Trump.jpg"/><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:image:src" content="http://www.gannett-cdn.com/-mm-/36a8da29397dc5af63ecb154b020ae6405f1fa18/c=0-231-4545-2799&amp;r=x453&amp;c=800x450/local/-/media/2016/02/03/USATODAY/USATODAY/635900913199306400-AP-GOP-2016-Trump.jpg" /><meta itemprop="dateModified" content="2016-02-03T14:54:46.0400000"/><meta itemprop="datePublished" content="2016-02-03T10:24:01.9400000"/><meta itemprop="articleSection" content="news,politics,onpolitics"/><meta name="twitter:site" content="@usatoday" /><meta name="twitter:creator" content="@usatoday" /><meta name="twitter:title" content="Donald Trump says Ted Cruz &#39;stole&#39; Iowa" /><meta name="twitter:description" content="Suffice it to say, he&#39;s not so congratulatory anymore." /><meta property="og:title" content="Donald Trump says Ted Cruz \\\'stole\\\' Iowa"/><meta property="og:description" content="Suffice it to say, he&#39;s not so congratulatory anymore."/><meta property="og:url" content="http://www.usatoday.com/story/news/politics/onpolitics/2016/02/03/donald-trump-ted-cruz-iowa-caucuses/79748926/"/><meta property="og:type" content="article"/><meta name="news_keywords" content="Ted Cruz, Donald Trump, Iowa caucuses" /><meta name="cXenseParse:recs:articleid" content="79748926" /><meta name="cXenseParse:pageclass" content="article" /><meta name="cXenseParse:recs:publishtime" content="2016-02-03T14:54:46.0400000" /><meta name="cXenseParse:recs:category" content="news/politics/onpolitics" /><meta name="cXenseParse:title" content="Donald Trump says Ted Cruz &#39;stole&#39; Iowa" /><meta name="cXenseParse:author" content="Cooper Allen" /><meta name="cXenseParse:recs:contenttype" content="story" /><meta name="cXenseParse:gci_asset_type" content="story" /><meta name="cXenseParse:recs:image-16_9" content="http://www.gannett-cdn.com/-mm-/7680163b975f4629df0f2b6eb1b6a088c5979132/c=0-231-4545-2799/local/-/media/2016/02/03/USATODAY/USATODAY/635900913199306400-AP-GOP-2016-Trump.jpg" /><meta name="cXenseParse:recs:image-4_3" content="http://www.gannett-cdn.com/-mm-/4322fdcbbe79e73b90336a9c219bed3f048c9655/c=258-0-4288-3030/local/-/media/2016/02/ ...

# %%
from nltk import word_tokenize

def get_words(a):
    """Return list of representative words from an article 
    html."""
    
    words = []
    
    soup = bs(a, 'lxml')
    for p in soup.find_all('p', class_=None):
        text = p.get_text()
        words += word_tokenize(text.lower())

    return words

# %%
article = fetch('http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/')
article
# Out:
# Retrieving from cache: http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/
# 'b\'<!doctype html><!--[if IE 8]><html class="no-js lt-ie10 lt-ie9" lang="en"><![endif]--><!--[if IE 9]><html class="no-js lt-ie10" lang="en"><![endif]--><!--[if gt IE 10]><!--><html class="no-js" lang="en"  itemscope itemtype="http://schema.org/NewsArticle" ><!--<![endif]--><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"><title>Trump: New Hampshire \\\'probably suits me better\\\'</title><meta content="text/html; charset=UTF-8" name="Content-Type" /><meta name="google" content="notranslate"><meta name="description" itemprop="description" content="Finishing second? It&#39;s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses."><link rel="canonical" href="http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/"><meta property="fb:app_id" content="215046668549694"/><meta property="og:site_name" content="USA TODAY" /><meta name="ROBOTS" content="NOODP, NOYDIR" /><meta property="og:image" content="http://www.gannett-cdn.com/-mm-/341070c63f94c401d71e3071bcabf7ba2c35564c/c=0-125-3802-2273&amp;r=x633&amp;c=1600x630/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/><meta property="og:image:width" content="1600" /><meta property="og:image:height" content="630" /><meta itemprop="thumbnailUrl" content="http://www.gannett-cdn.com/-mm-/a9b1c8ab5d1f0e2c8d37e206f01f157777734d16/c=811-0-3349-2538&amp;r=x153&amp;c=150x150/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/><meta itemprop="thumbnailHeight" content="150"/><meta itemprop="thumbnailWidth" content="150"/><meta itemprop="image" content="http://www.gannett-cdn.com/-mm-/662f67e3f37f6175236b8c874168e9654598fb28/c=811-0-3349-2538&amp;r=x203&amp;c=200x200/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg"/><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:image:src" content="http://www.gannett-cdn.com/-mm-/310cb64b10c34935ac6c5acbea066dcdb3550c3a/c=0-125-3802-2273&amp;r=x453&amp;c=800x450/local/-/media/2016/02/02/USATODAY/USATODAY/635900408041090489-AP-GOP-2016-Trump.jpg" /><meta itemprop="dateModified" content="2016-02-03T08:41:44.6900000"/><meta itemprop="datePublished" content="2016-02-02T20:15:29.2170000"/><meta itemprop="articleSection" content="news,politics,onpolitics"/><meta name="twitter:site" content="@usatoday" /><meta name="twitter:creator" content="@usatoday" /><meta name="twitter:title" content="Trump: New Hampshire &#39;probably suits me better&#39;" /><meta name="twitter:description" content="Finishing second? It&#39;s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses." /><meta property="og:title" content="Trump: New Hampshire \\\'probably suits me better\\\'"/><meta property="og:description" content="Finishing second? It&#39;s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated him in the Iowa caucuses."/><meta property="og:url" content="http://www.usatoday.com/story/news/politics/onpolitics/2016/02/02/trump-new-hampshire-probably-suits-me-better/79726718/"/><meta property="og:type" content="article"/><meta name="news_keywords" content="Donald Trump, Iowa caucuses, New Hampshire primary, Republicans" /><meta name="cXenseParse:recs:articleid" content="79726718" /><meta name="cXenseParse:pageclass" content="article" /><meta name="cXenseParse:recs:publishtime" content="2016-02-03T08:41:44.6900000" /><meta name="cXenseParse:recs:category" content="news/politics/onpolitics" /><meta name="cXenseParse:title" content="Trump: New Hampshire &#39;probably suits me better&#39;" /><meta name="cXenseParse:author" content="Susan Page" /><meta name="cXenseParse:recs:contenttype" content="story" /><meta name="cXenseParse:gci_asset_type ...

# %%
soup = bs(article, 'lxml')
p_set = soup.find_all('p', class_=None)
paragraphs = [p.get_text() for p in p_set]
paragraphs
# Out:
# ["b'",
#  "MILFORD, N.H. \\xe2\\x80\\x94\\xc2\\xa0Finishing second? It\\'s not so bad, Donald Trump told a cheering rally in New Hampshire less than 24 hours after Texas Sen. Ted Cruz defeated \\xc2\\xa0him in the Iowa caucuses.",
#  '"I think we did really well, we did really well," Trump declared Tuesday night in his first public appearance since he failed to meet expectations that he would win the opening Iowa caucuses. He said his decision to skip the final Iowa debate in a dispute with Fox News might have cost him some support, but he cast it as an act of philanthropy because he hosted instead a fundraiser to help U.S. military vets.',
#  '"I\\\'ll take the $6 million for the vets" over a first-place finish, he declared.',
#  'Donald Trump speaks with members of the media during a news conference on Feb. 2, 2016, in Milford, N.H.\xa0(Photo: Matt Rourke, AP)',
#  'Trump delivered an energetic rambling address to an enthusiastic crowd of thousands of people in a sports facility on a cold winter night, a sharp contrast to the town-hall meetings characteristic of New Hampshire in which citizens quiz candidates.',
#  'He was introduced by former Massachusetts senator Scott Brown, who endorsed \\xc2\\xa0Trump as "an agent of change" who could "shake up the status quo in Washington."',
#  'Trump accused the news media of misrepresenting his Iowa finish, disputing the idea that the third-place finish by Florida Sen. Marco Rubio was somehow noteworthy.',
#  '"He\\\'s a professional politician; he comes in third; I come in second." He mocked the headlines that he said followed. "Trump: \\\'No good.\\\' Rubio: \\\'Incredible night!\\\' "',
#  'In a news conference before the rally, Trump took a determinedly low-key tone. He said he couldn\\\'t think of any mistakes his campaign had made in Iowa or any lessons he had learned there. He depicted his finish as remarkably good given his low standing when he launched his campaign. Late Iowa polls that showed him with a lead "maybe built a false expectation."',
#  'New Hampshire is likely to be a friendlier landscape, he said. "I think it fits me better, probably suits me better."',
#  'Would he be OK with finished second in New Hampshire, too?',
#  '"Finishing second wouldn\\\'t be the worst thing in the world," he said. Even so, he allowed, "I\\\'d like to finish first."']

# %%
words = []
for para in paragraphs:
    words += nltk.word_tokenize(para)
words
# Out:
# ['b',
#  "'",
#  'MILFORD',
#  ',',
#  'N.H.',
#  '\\xe2\\x80\\x94\\xc2\\xa0Finishing',
#  'second',
#  '?',
#  'It\\',
#  "'s",
#  'not',
#  'so',
#  'bad',
#  ',',
#  'Donald',
#  'Trump',
#  'told',
#  'a',
#  'cheering',
#  'rally',
#  'in',
#  'New',
#  'Hampshire',
#  'less',
#  'than',
#  '24',
#  'hours',
#  'after',
#  'Texas',
#  'Sen.',
#  'Ted',
#  'Cruz',
#  'defeated',
#  '\\xc2\\xa0him',
#  'in',
#  'the',
#  'Iowa',
#  'caucuses',
#  '.',
#  '``',
#  'I',
#  'think',
#  'we',
#  'did',
#  'really',
#  'well',
#  ',',
#  'we',
#  'did',
#  'really',
#  'well',
#  ',',
#  "''",
#  'Trump',
#  'declared',
#  'Tuesday',
#  'night',
#  'in',
#  'his',
#  'first',
#  'public',
#  'appearance',
#  'since',
#  'he',
#  'failed',
#  'to',
#  'meet',
#  'expectations',
#  'that',
#  'he',
#  'would',
#  'win',
#  'the',
#  'opening',
#  'Iowa',
#  'caucuses',
#  '.',
#  'He',
#  'said',
#  'his',
#  'decision',
#  'to',
#  'skip',
#  'the',
#  'final',
#  'Iowa',
#  'debate',
#  'in',
#  'a',
#  'dispute',
#  'with',
#  'Fox',
#  'News',
#  'might',
#  'have',
#  'cost',
#  'him',
#  'some',
#  'support',
#  ',',
#  'but',
#  'he',
#  'cast',
#  'it',
#  'as',
#  'an',
#  'act',
#  'of',
#  'philanthropy',
#  'because',
#  'he',
#  'hosted',
#  'instead',
#  'a',
#  'fundraiser',
#  'to',
#  'help',
#  'U.S.',
#  'military',
#  'vets',
#  '.',
#  '``',
#  'I\\',
#  "'ll",
#  'take',
#  'the',
#  '$',
#  '6',
#  'million',
#  'for',
#  'the',
#  'vets',
#  "''",
#  'over',
#  'a',
#  'first-place',
#  'finish',
#  ',',
#  'he',
#  'declared',
#  '.',
#  'Donald',
#  'Trump',
#  'speaks',
#  'with',
#  'members',
#  'of',
#  'the',
#  'media',
#  'during',
#  'a',
#  'news',
#  'conference',
#  'on',
#  'Feb.',
#  '2',
#  ',',
#  '2016',
#  ',',
#  'in',
#  'Milford',
#  ',',
#  'N.H.',
#  '(',
#  'Photo',
#  ':',
#  'Matt',
#  'Rourke',
#  ',',
#  'AP',
#  ')',
#  'Trump',
#  'delivered',
#  'an',
#  'energetic',
#  'rambling',
#  'address',
#  'to',
#  'an',
#  'enthusiastic',
#  'crowd',
#  'of',
#  'thousands',
#  'of',
#  'people',
#  'in',
#  'a',
#  'sports',
#  'facility',
#  'on',
#  'a',
#  'cold',
#  'winter',
#  'night',
#  ',',
#  'a',
#  'sharp',
#  'contrast',
#  'to',
#  'the',
#  'town-hall',
#  'meetings',
#  'characteristic',
#  'of',
#  'New',
#  'Hampshire',
#  'in',
#  'which',
#  'citizens',
#  'quiz',
#  'candidates',
#  '.',
#  'He',
#  'was',
#  'introduced',
#  'by',
#  'former',
#  'Massachusetts',
#  'senator',
#  'Scott',
#  'Brown',
#  ',',
#  'who',
#  'endorsed',
#  '\\xc2\\xa0Trump',
#  'as',
#  '``',
#  'an',
#  'agent',
#  'of',
#  'change',
#  "''",
#  'who',
#  'could',
#  '``',
#  'shake',
#  'up',
#  'the',
#  'status',
#  'quo',
#  'in',
#  'Washington',
#  '.',
#  "''",
#  'Trump',
#  'accused',
#  'the',
#  'news',
#  'media',
#  'of',
#  'misrepresenting',
#  'his',
#  'Iowa',
#  'finish',
#  ',',
#  'disputing',
#  'the',
#  'idea',
#  'that',
#  'the',
#  'third-place',
#  'finish',
#  'by',
#  'Florida',
#  'Sen.',
#  'Marco',
#  'Rubio',
#  'was',
#  'somehow',
#  'noteworthy',
#  '.',
#  '``',
#  'He\\',
#  "'s",
#  'a',
#  'professional',
#  'politician',
#  ';',
#  'he',
#  'comes',
#  'in',
#  'third',
#  ';',
#  'I',
#  'come',
#  'in',
#  'second',
#  '.',
#  "''",
#  'He',
#  'mocked',
#  'the',
#  'headlines',
#  'that',
#  'he',
#  'said',
#  'followed',
#  '.',
#  '``',
#  'Trump',
#  ':',
#  "\\'No",
#  'good.\\',
#  "'",
#  'Rubio',
#  ':',
#  "\\'Incredible",
#  'night',
#  '!',
#  '\\',
#  "'",
#  '``',
#  'In',
#  'a',
#  'news',
#  'conference',
#  'before',
#  'the',
#  'rally',
#  ',',
#  'Trump',
#  'took',
#  'a',
#  'determinedly',
#  'low-key',
#  'tone',
#  '.',
#  'He',
#  'said',
#  'he',
#  "couldn\\'t",
#  'think',
#  'of',
#  'any',
#  'mistakes',
#  'his',
#  'campaign',
#  'had',
#  'made',
#  'in',
#  'Iowa',
#  'or',
#  'any',
#  'lessons',
#  'he',
#  'had',
#  'learned',
#  'there',
#  '.',
#  'He',
#  'depicted',
#  'his',
#  'finish',
#  'as',
#  'remarkably',
#  'good',
#  'given',
#  'his',
#  'low',
#  'standing',
#  'when',
#  'he',
#  'launched',
#  'his',
#  'campaign',
#  '.',
#  'Late',
#  'Iowa',
#  'polls',
#  'that',
#  'showed',
#  'him',
#  'with',
#  'a',
#  'lead',
#  '``',
#  'maybe',
#  'built',
#  'a',
#  'false',
#  'expectation',
#  '.',
#  "''",
#  'New',
#  'Hampshire',
#  'is',
#  'likely',
#  'to',
#  'be',
#  'a',
#  'friendlier',
#  'landscape',
#  ',',
#  'he',
#  'said',
#  '.',
#  '``',
#  'I',
#  'think',
#  'it',
#  'fits',
#  'me',
#  'better',
#  ',',
#  'probably',
#  'suits',
#  'me',
#  'better',
#  '.',
#  "''",
#  'Would',
#  'he',
#  'be',
#  'OK',
#  'with',
#  'finished',
#  'second',
#  'in',
#  'New',
#  'Hampshire',
#  ',',
#  'too',
#  '?',
#  '``',
#  'Finishing',
#  'second',
#  "wouldn\\'t",
#  'be',
#  'the',
#  'worst',
#  'thing',
#  'in',
#  'the',
#  'world',
#  ',',
#  "''",
#  'he',
#  'said',
#  '.',
#  'Even',
#  'so',
#  ',',
#  'he',
#  'allowed',
#  ',',
#  '``',
#  'I\\',
#  "'d",
#  'like',
#  'to',
#  'finish',
#  'first',
#  '.',
#  "''"]

# %% [markdown]
# ## 2. Get text from PDF

# %% [markdown]
# To install: run the following code in your terminal
# ####  *sudo pip install pyPDF2*

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader
input_file = PdfFileReader(open("document.pdf", "rb"))

# %%
input_file.getNumPages()
# Out:
# 12

# %%
input_file.getPage(0).extractText()
# Out:
# 'Proceedings of the 2010 Winter Simulation Conference \nB. Johansson, S. Jain, J. Montoya-Torres, J. Hugan, and E. Yücesan, eds. \n   TO AGENT-BASED SIMULATION FROM SYSTEM DYNAMICS \n Charles M. Macal \n Argonne National Laboratory \nCenter for Complex Adaptive Agent Systems Simulation (CAS\n2) \n9700 S. Cass Ave. \nArgonne, IL 60439, USA \n ABSTRACT \nAgent-based simulation (ABS) is a recent modeling technique that is being widely used in modeling \ncomplex social systems. Forrester™s System Dynamics (SD) is another longstanding technique for model-\ning social systems. Several classical models of systems, such as the Kermack-McKendrick model of epi-\n\ndemiology, the Lotka-Volterra equations for modeling predator-prey relationships, and the Bass model for \ninnovation diffusion are formulated as systems of differential equations and have corresponding System \nDynamics representations as difference equations. The ABS and SD modeling approaches take funda-\nmentally different perspectives when modeling a system, which can be characterized as bottom-up (ABS) \nversus top-down (SD). Yet many systems can be equivalently modeled by either approach. In this paper, \n\nwe present a formal specification for SD and ABS models, use the specification to derive equivalent ABS \nrepresentations, and present an example of an SIR epidemic model having SD and ABS counterparts. \n1 INTRODUCTION \nForrester™s System Dynamics (SD) is a commonly used systems modeling technique with a long tradition \nof applications to social systems (Forrester 1961; Forrester 1971; Roberts et al. 1983, Sterman, 2000). \n\nSystems Dynamics models consist of a set of difference equations (similar to differential equations but \nwith a fixed time step) that are recursively solved forward through time. In general, SD models consist of \na relatively small number of state variables that completely define the state of the system being modeled, \nand a specification of the rate of change of each of the state variables, which depends on the previous sys-\ntem state. SD has its roots in dynamic systems and control theory, and emphasizes the importance of \n\nfeedback effects between aggregate level system components as strong determinants of system behavior. \n Agent-based simulation (ABS) is a relatively recent modeling technique that is being widely used to \nmodel complex systems composed of interacting, autonomous ﬁagentsﬂ (Epstein and Axtell 1996, Bona-\nbeau 2001, North and Macal 2007, Macal and North 2009). Agents have behaviors, which are often de-\nscribed by simple rules. Agents interact with and influence each other, learn from their experiences, and \n\nadapt their behaviors so they are better suited to their environment. By modeling agents individually, the \nfull effects of the diversity that exists among agents with respect to their attributes and behaviors can be \nobserved as they give rise to the dynamic behavior of the system as a whole.  \n The ABS and SD modeling approaches take fundamentally different perspectives when modeling a \nsystem, which has been characterized as bottom-up (ABS), i.e., modeling a system by modeling the indi-\nvidual entities that compose the system and their interactions, versus top-down (SD), i.e., modeling a sys-\ntem by breaking it into its major components and modeling the component interactions. Yet many sys-\n\ntems can be modeled by either the SD or ABS approach, as has been noted by several researchers. For \nexample, Scholl (2001) describes agent-based modeling and System Dynamics as two prominent tech-\nniques for modeling nonlinear systems and identifies areas in which the two modeling traditions overlap \nas well as complement each other, concluding with a call for more research on the subject. Comparing the \n371978-1-4244-9865-9/10/$26.00 ©2010 IEEE'

# %%
text = ''
for page_id in range(input_file.getNumPages()):
    text += input_file.getPage(page_id).extractText()
text
# Out:
# 'Proceedings of the 2010 Winter Simulation Conference \nB. Johansson, S. Jain, J. Montoya-Torres, J. Hugan, and E. Yücesan, eds. \n   TO AGENT-BASED SIMULATION FROM SYSTEM DYNAMICS \n Charles M. Macal \n Argonne National Laboratory \nCenter for Complex Adaptive Agent Systems Simulation (CAS\n2) \n9700 S. Cass Ave. \nArgonne, IL 60439, USA \n ABSTRACT \nAgent-based simulation (ABS) is a recent modeling technique that is being widely used in modeling \ncomplex social systems. Forrester™s System Dynamics (SD) is another longstanding technique for model-\ning social systems. Several classical models of systems, such as the Kermack-McKendrick model of epi-\n\ndemiology, the Lotka-Volterra equations for modeling predator-prey relationships, and the Bass model for \ninnovation diffusion are formulated as systems of differential equations and have corresponding System \nDynamics representations as difference equations. The ABS and SD modeling approaches take funda-\nmentally different perspectives when modeling a system, which can be characterized as bottom-up (ABS) \nversus top-down (SD). Yet many systems can be equivalently modeled by either approach. In this paper, \n\nwe present a formal specification for SD and ABS models, use the specification to derive equivalent ABS \nrepresentations, and present an example of an SIR epidemic model having SD and ABS counterparts. \n1 INTRODUCTION \nForrester™s System Dynamics (SD) is a commonly used systems modeling technique with a long tradition \nof applications to social systems (Forrester 1961; Forrester 1971; Roberts et al. 1983, Sterman, 2000). \n\nSystems Dynamics models consist of a set of difference equations (similar to differential equations but \nwith a fixed time step) that are recursively solved forward through time. In general, SD models consist of \na relatively small number of state variables that completely define the state of the system being modeled, \nand a specification of the rate of change of each of the state variables, which depends on the previous sys-\ntem state. SD has its roots in dynamic systems and control theory, and emphasizes the importance of \n\nfeedback effects between aggregate level system components as strong determinants of system behavior. \n Agent-based simulation (ABS) is a relatively recent modeling technique that is being widely used to \nmodel complex systems composed of interacting, autonomous ﬁagentsﬂ (Epstein and Axtell 1996, Bona-\nbeau 2001, North and Macal 2007, Macal and North 2009). Agents have behaviors, which are often de-\nscribed by simple rules. Agents interact with and influence each other, learn from their experiences, and \n\nadapt their behaviors so they are better suited to their environment. By modeling agents individually, the \nfull effects of the diversity that exists among agents with respect to their attributes and behaviors can be \nobserved as they give rise to the dynamic behavior of the system as a whole.  \n The ABS and SD modeling approaches take fundamentally different perspectives when modeling a \nsystem, which has been characterized as bottom-up (ABS), i.e., modeling a system by modeling the indi-\nvidual entities that compose the system and their interactions, versus top-down (SD), i.e., modeling a sys-\ntem by breaking it into its major components and modeling the component interactions. Yet many sys-\n\ntems can be modeled by either the SD or ABS approach, as has been noted by several researchers. For \nexample, Scholl (2001) describes agent-based modeling and System Dynamics as two prominent tech-\nniques for modeling nonlinear systems and identifies areas in which the two modeling traditions overlap \nas well as complement each other, concluding with a call for more research on the subject. Comparing the \n371978-1-4244-9865-9/10/$26.00 ©2010 IEEEMacal \n SD and ABS approaches to modeling the same problem has been addressed by Parunack (1998) in model-\ning supply chains, Marin et al. (2006) in work force m ...

# %%
nltk.word_tokenize(text)
# Out:
# ['Proceedings',
#  'of',
#  'the',
#  '2010',
#  'Winter',
#  'Simulation',
#  'Conference',
#  'B.',
#  'Johansson',
#  ',',
#  'S.',
#  'Jain',
#  ',',
#  'J.',
#  'Montoya-Torres',
#  ',',
#  'J.',
#  'Hugan',
#  ',',
#  'and',
#  'E.',
#  'Yücesan',
#  ',',
#  'eds',
#  '.',
#  'TO',
#  'AGENT-BASED',
#  'SIMULATION',
#  'FROM',
#  'SYSTEM',
#  'DYNAMICS',
#  'Charles',
#  'M.',
#  'Macal',
#  'Argonne',
#  'National',
#  'Laboratory',
#  'Center',
#  'for',
#  'Complex',
#  'Adaptive',
#  'Agent',
#  'Systems',
#  'Simulation',
#  '(',
#  'CAS',
#  '2',
#  ')',
#  '9700',
#  'S.',
#  'Cass',
#  'Ave.',
#  'Argonne',
#  ',',
#  'IL',
#  '60439',
#  ',',
#  'USA',
#  'ABSTRACT',
#  'Agent-based',
#  'simulation',
#  '(',
#  'ABS',
#  ')',
#  'is',
#  'a',
#  'recent',
#  'modeling',
#  'technique',
#  'that',
#  'is',
#  'being',
#  'widely',
#  'used',
#  'in',
#  'modeling',
#  'complex',
#  'social',
#  'systems',
#  '.',
#  'Forrester™s',
#  'System',
#  'Dynamics',
#  '(',
#  'SD',
#  ')',
#  'is',
#  'another',
#  'longstanding',
#  'technique',
#  'for',
#  'model-',
#  'ing',
#  'social',
#  'systems',
#  '.',
#  'Several',
#  'classical',
#  'models',
#  'of',
#  'systems',
#  ',',
#  'such',
#  'as',
#  'the',
#  'Kermack-McKendrick',
#  'model',
#  'of',
#  'epi-',
#  'demiology',
#  ',',
#  'the',
#  'Lotka-Volterra',
#  'equations',
#  'for',
#  'modeling',
#  'predator-prey',
#  'relationships',
#  ',',
#  'and',
#  'the',
#  'Bass',
#  'model',
#  'for',
#  'innovation',
#  'diffusion',
#  'are',
#  'formulated',
#  'as',
#  'systems',
#  'of',
#  'differential',
#  'equations',
#  'and',
#  'have',
#  'corresponding',
#  'System',
#  'Dynamics',
#  'representations',
#  'as',
#  'difference',
#  'equations',
#  '.',
#  'The',
#  'ABS',
#  'and',
#  'SD',
#  'modeling',
#  'approaches',
#  'take',
#  'funda-',
#  'mentally',
#  'different',
#  'perspectives',
#  'when',
#  'modeling',
#  'a',
#  'system',
#  ',',
#  'which',
#  'can',
#  'be',
#  'characterized',
#  'as',
#  'bottom-up',
#  '(',
#  'ABS',
#  ')',
#  'versus',
#  'top-down',
#  '(',
#  'SD',
#  ')',
#  '.',
#  'Yet',
#  'many',
#  'systems',
#  'can',
#  'be',
#  'equivalently',
#  'modeled',
#  'by',
#  'either',
#  'approach',
#  '.',
#  'In',
#  'this',
#  'paper',
#  ',',
#  'we',
#  'present',
#  'a',
#  'formal',
#  'specification',
#  'for',
#  'SD',
#  'and',
#  'ABS',
#  'models',
#  ',',
#  'use',
#  'the',
#  'specification',
#  'to',
#  'derive',
#  'equivalent',
#  'ABS',
#  'representations',
#  ',',
#  'and',
#  'present',
#  'an',
#  'example',
#  'of',
#  'an',
#  'SIR',
#  'epidemic',
#  'model',
#  'having',
#  'SD',
#  'and',
#  'ABS',
#  'counterparts',
#  '.',
#  '1',
#  'INTRODUCTION',
#  'Forrester™s',
#  'System',
#  'Dynamics',
#  '(',
#  'SD',
#  ')',
#  'is',
#  'a',
#  'commonly',
#  'used',
#  'systems',
#  'modeling',
#  'technique',
#  'with',
#  'a',
#  'long',
#  'tradition',
#  'of',
#  'applications',
#  'to',
#  'social',
#  'systems',
#  '(',
#  'Forrester',
#  '1961',
#  ';',
#  'Forrester',
#  '1971',
#  ';',
#  'Roberts',
#  'et',
#  'al',
#  '.',
#  '1983',
#  ',',
#  'Sterman',
#  ',',
#  '2000',
#  ')',
#  '.',
#  'Systems',
#  'Dynamics',
#  'models',
#  'consist',
#  'of',
#  'a',
#  'set',
#  'of',
#  'difference',
#  'equations',
#  '(',
#  'similar',
#  'to',
#  'differential',
#  'equations',
#  'but',
#  'with',
#  'a',
#  'fixed',
#  'time',
#  'step',
#  ')',
#  'that',
#  'are',
#  'recursively',
#  'solved',
#  'forward',
#  'through',
#  'time',
#  '.',
#  'In',
#  'general',
#  ',',
#  'SD',
#  'models',
#  'consist',
#  'of',
#  'a',
#  'relatively',
#  'small',
#  'number',
#  'of',
#  'state',
#  'variables',
#  'that',
#  'completely',
#  'define',
#  'the',
#  'state',
#  'of',
#  'the',
#  'system',
#  'being',
#  'modeled',
#  ',',
#  'and',
#  'a',
#  'specification',
#  'of',
#  'the',
#  'rate',
#  'of',
#  'change',
#  'of',
#  'each',
#  'of',
#  'the',
#  'state',
#  'variables',
#  ',',
#  'which',
#  'depends',
#  'on',
#  'the',
#  'previous',
#  'sys-',
#  'tem',
#  'state',
#  '.',
#  'SD',
#  'has',
#  'its',
#  'roots',
#  'in',
#  'dynamic',
#  'systems',
#  'and',
#  'control',
#  'theory',
#  ',',
#  'and',
#  'emphasizes',
#  'the',
#  'importance',
#  'of',
#  'feedback',
#  'effects',
#  'between',
#  'aggregate',
#  'level',
#  'system',
#  'components',
#  'as',
#  'strong',
#  'determinants',
#  'of',
#  'system',
#  'behavior',
#  '.',
#  'Agent-based',
#  'simulation',
#  '(',
#  'ABS',
#  ')',
#  'is',
#  'a',
#  'relatively',
#  'recent',
#  'modeling',
#  'technique',
#  'that',
#  'is',
#  'being',
#  'widely',
#  'used',
#  'to',
#  'model',
#  'complex',
#  'systems',
#  'composed',
#  'of',
#  'interacting',
#  ',',
#  'autonomous',
#  'ﬁagentsﬂ',
#  '(',
#  'Epstein',
#  'and',
#  'Axtell',
#  '1996',
#  ',',
#  'Bona-',
#  'beau',
#  '2001',
#  ',',
#  'North',
#  'and',
#  'Macal',
#  '2007',
#  ',',
#  'Macal',
#  'and',
#  'North',
#  '2009',
#  ')',
#  '.',
#  'Agents',
#  'have',
#  'behaviors',
#  ',',
#  'which',
#  'are',
#  'often',
#  'de-',
#  'scribed',
#  'by',
#  'simple',
#  'rules',
#  '.',
#  'Agents',
#  'interact',
#  'with',
#  'and',
#  'influence',
#  'each',
#  'other',
#  ',',
#  'learn',
#  'from',
#  'their',
#  'experiences',
#  ',',
#  'and',
#  'adapt',
#  'their',
#  'behaviors',
#  'so',
#  'they',
#  'are',
#  'better',
#  'suited',
#  'to',
#  'their',
#  'environment',
#  '.',
#  'By',
#  'modeling',
#  'agents',
#  'individually',
#  ',',
#  'the',
#  'full',
#  'effects',
#  'of',
#  'the',
#  'diversity',
#  'that',
#  'exists',
#  'among',
#  'agents',
#  'with',
#  'respect',
#  'to',
#  'their',
#  'attributes',
#  'and',
#  'behaviors',
#  'can',
#  'be',
#  'observed',
#  'as',
#  'they',
#  'give',
#  'rise',
#  'to',
#  'the',
#  'dynamic',
#  'behavior',
#  'of',
#  'the',
#  'system',
#  'as',
#  'a',
#  'whole',
#  '.',
#  'The',
#  'ABS',
#  'and',
#  'SD',
#  'modeling',
#  'approaches',
#  'take',
#  'fundamentally',
#  'different',
#  'perspectives',
#  'when',
#  'modeling',
#  'a',
#  'system',
#  ',',
#  'which',
#  'has',
#  'been',
#  'characterized',
#  'as',
#  'bottom-up',
#  '(',
#  'ABS',
#  ')',
#  ',',
#  'i.e.',
#  ',',
#  'modeling',
#  'a',
#  'system',
#  'by',
#  'modeling',
#  'the',
#  'indi-',
#  'vidual',
#  'entities',
#  'that',
#  'compose',
#  'the',
#  'system',
#  'and',
#  'their',
#  'interactions',
#  ',',
#  'versus',
#  'top-down',
#  '(',
#  'SD',
#  ')',
#  ',',
#  'i.e.',
#  ',',
#  'modeling',
#  'a',
#  'sys-',
#  'tem',
#  'by',
#  'breaking',
#  'it',
#  'into',
#  'its',
#  'major',
#  'components',
#  'and',
#  'modeling',
#  'the',
#  'component',
#  'interactions',
#  '.',
#  'Yet',
#  'many',
#  'sys-',
#  'tems',
#  'can',
#  'be',
#  'modeled',
#  'by',
#  'either',
#  'the',
#  'SD',
#  'or',
#  'ABS',
#  'approach',
#  ',',
#  'as',
#  'has',
#  'been',
#  'noted',
#  'by',
#  'several',
#  'researchers',
#  '.',
#  'For',
#  'example',
#  ',',
#  'Scholl',
#  '(',
#  '2001',
#  ')',
#  'describes',
#  'agent-based',
#  'modeling',
#  'and',
#  'System',
#  'Dynamics',
#  'as',
#  'two',
#  'prominent',
#  'tech-',
#  'niques',
#  'for',
#  'modeling',
#  'nonlinear',
#  'systems',
#  'and',
#  'identifies',
#  'areas',
#  'in',
#  'which',
#  'the',
#  'two',
#  'modeling',
#  'traditions',
#  'overlap',
#  'as',
#  'well',
#  'as',
#  'complement',
#  'each',
#  'other',
#  ',',
#  'concluding',
#  'with',
#  'a',
#  'call',
#  'for',
#  'more',
#  'research',
#  'on',
#  'the',
#  'subject',
#  '.',
#  'Comparing',
#  'the',
#  '371978-1-4244-9865-9/10/',
#  '$',
#  '26.00',
#  '©2010',
#  'IEEEMacal',
#  'SD',
#  'and',
#  'ABS',
#  'approaches',
#  'to',
#  'modeling',
#  'the',
#  'same',
#  'problem',
#  'has',
#  'been',
#  'addressed',
#  'by',
#  'Parunack',
#  '(',
#  '1998',
#  ')',
#  'in',
#  'model-',
#  'ing',
#  'supply',
#  'chains',
#  ',',
#  'Marin',
#  'et',
#  'al',
#  '.',
#  '(',
#  '2006',
#  ')',
#  'in',
#  'work',
#  'force',
#  'modeling',
#  ',',
#  'and',
#  'Norlin',
#  '(',
#  '2007',
#  ')',
#  'in',
#  'modeling',
#  'ecologies',
#  ',',
#  'among',
#  'others',
#  '.',
#  'Several',
#  'classical',
#  'system',
#  'models',
#  ',',
#  'such',
#  'as',
#  'the',
#  'Kermack-McKendrick',
#  'model',
#  'of',
#  'epidemic',
#  'dynamics',
#  '(',
#  'Kermack',
#  'and',
#  'McKendrick',
#  '1927',
#  ')',
#  ',',
#  'the',
#  'Lotka-Volterra',
#  'equations',
#  'for',
#  'modeling',
#  'predator-prey',
#  'relationships',
#  ',',
#  'the',
#  'Bass',
#  'model',
#  'for',
#  'innovation',
#  'diffusion',
#  ',',
#  'chemical',
#  'kinetics',
#  'models',
#  ',',
#  'and',
#  'many',
#  'others',
#  'are',
#  'formulated',
#  'as',
#  'systems',
#  'of',
#  'ordinary',
#  'differential',
#  'equations',
#  'and',
#  'have',
#  'corresponding',
#  'System',
#  'Dynamics',
#  'representations',
#  'as',
#  'difference',
#  'equations',
#  '.',
#  'It',
#  'is',
#  'well-known',
#  'that',
#  'the',
#  'Kermack-McKendrick',
#  'model',
#  'in',
#  'particular',
#  'can',
#  'be',
#  'formu-',
#  'lated',
#  'as',
#  'an',
#  'agent-based',
#  'simulation',
#  'also',
#  ',',
#  'and',
#  'produces',
#  'similar',
#  'results',
#  'to',
#  'an',
#  'SD',
#  'formulation',
#  '(',
#  'Bagni',
#  'et',
#  'al',
#  '.',
#  '2002',
#  ',',
#  'Borshchev',
#  'and',
#  'Filippov',
#  '2004',
#  ',',
#  'Wakeland',
#  'et',
#  'al',
#  '.',
#  '2004',
#  ',',
#  'Epstein',
#  'et',
#  'al',
#  '.',
#  '2008',
#  ',',
#  'Rahmandad',
#  'and',
#  'Sterman',
#  '2008',
#  ')',
#  '.',
#  'In',
#  'this',
#  'paper',
#  ',',
#  'we',
#  'elaborate',
#  'on',
#  'this',
#  'similarity',
#  'and',
#  'describe',
#  'the',
#  'specifics',
#  'of',
#  'how',
#  'to',
#  'transform',
#  'a',
#  'Sys-',
#  'tem',
#  'Dynamics',
#  'model',
#  'into',
#  'an',
#  'ﬁequivalentﬂ',
#  'ABS',
#  'model',
#  '.',
#  'By',
#  'equivalent',
#  ',',
#  'we',
#  'mean',
#  'that',
#  'both',
#  'models',
#  'represent',
#  'the',
#  'same',
#  'system',
#  'down',
#  'to',
#  'its',
#  'detailed',
#  'specifications',
#  'using',
#  'the',
#  'fullest',
#  'capabilities',
#  'that',
#  'each',
#  'ap-',
#  'proach',
#  'can',
#  'provide',
#  '.',
#  'The',
#  'equivalent',
#  'SD',
#  'and',
#  'AB',
#  'models',
#  'are',
#  'different',
#  'in',
#  'form',
#  'and',
#  'do',
#  'not',
#  'necessarily',
#  'pro-',
#  'duce',
#  'the',
#  'same',
#  'numerical',
#  'results',
#  'given',
#  'identical',
#  'assumptions',
#  '.',
#  'We',
#  'will',
#  'illustrate',
#  'and',
#  'elaborate',
#  'on',
#  'this',
#  'equivalency',
#  'by',
#  'describing',
#  'how',
#  'to',
#  'transform',
#  'the',
#  'Kermack-McKendrick',
#  'SIR',
#  'model',
#  'of',
#  'epidemic',
#  'dynamics',
#  'into',
#  'an',
#  'agent-based',
#  'simulation',
#  'of',
#  'the',
#  'same',
#  'system',
#  '.',
#  'The',
#  'transformation',
#  'process',
#  'is',
#  'a',
#  'general',
#  'one',
#  ',',
#  'however',
#  ',',
#  'and',
#  'should',
#  'be',
#  'applicable',
#  'to',
#  'any',
#  'SD',
#  'model',
#  'that',
#  'has',
#  'strong',
#  'component',
#  ',',
#  'or',
#  'agent',
#  ',',
#  'interactions',
#  '.',
#  'This',
#  'paper',
#  'is',
#  'organized',
#  'as',
#  'follows',
#  '.',
#  'In',
#  'Section',
#  '2',
#  'we',
#  'provide',
#  'useful',
#  'definitions',
#  'of',
#  'SD',
#  'models',
#  'and',
#  'the',
#  'subset',
#  'of',
#  'the',
#  'type',
#  'of',
#  'agent-based',
#  'models',
#  'considered',
#  'in',
#  'this',
#  'paper',
#  '.',
#  'Section',
#  '3',
#  'describes',
#  'the',
#  'procedure',
#  'for',
#  'transforming',
#  'an',
#  'SD',
#  'model',
#  'into',
#  'two',
#  'equivalent',
#  'ABS',
#  'representations',
#  '.',
#  'Section',
#  '4',
#  ...]

# %% [markdown]
# ## 3. Get text from social media

# %% [markdown]
# To install: run the following code in your terminal
# ####  *sudo pip install python-twitter*

# %%
import twitter

CONSUMER_KEY = '<...>'
CONSUMER_SECRET = '<...>'
OAUTH_TOKEN = '<...>'
OAUTH_TOKEN_SECRET = '<...>'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %%
q = '#humanservices'
search_results = twitter_api.search.tweets(q=q, count=100)
search_results
statuses = search_results['statuses']

# %%
statuses[0]['text']
# Out:
# 'HSHS intro video 12 13 12 BC https://t.co/rNxMEAXNtI via @YouTube\n#Pathways #Academies #HumanServices #HealthSciences #CareerPath'

# %%
status_texts = [ status['text'] for status in statuses ]
status_texts
# Out:
# ['HSHS intro video 12 13 12 BC https://t.co/rNxMEAXNtI via @YouTube\n#Pathways #Academies #HumanServices #HealthSciences #CareerPath',
#  'The @MassCouncil analysis of the H2 Budget. #HumanServices #mapoli https://t.co/Sqp7iHSAYT',
#  'Want to help your #community? Discover #degrees in #HumanServices today! https://t.co/7w3F0yMt0M https://t.co/c651Fl26Ax',
#  'How can #HumanServices agencies move from #childsupport collections to collaboration? https://t.co/QeSoGJbY24 https://t.co/weIYxhpl5a',
#  'What exactly IS the National #HumanServices #Interoperability Architecture? (NHSIA) https://t.co/fQYznS4ipN',
#  'Why’s failure the key to success in #HumanServices? Read more https://t.co/4jjNrDxzT8 https://t.co/Ew8nzKJVkQ',
#  'Explore the journey towards a generative business model in #HumanServices  https://t.co/54qpBdVZk1',
#  'Shout out:\nLongstanding exemplary work @santamonicacity \n#housing  #humanservices \n@SantaMonicaPD \nto #endhomelessness \n@RANDCorporation',
#  'RT @AccenturePubSvc: #HumanServices like you’ve never seen it. Imagine the digital #childsupport agency. https://t.co/HcxyvHUy2A https://t.…',
#  'RT @AccenturePubSvc: What’s leadership got to do with the future of #HumanServices? Find out here https://t.co/RZFYUPvq58 https://t.co/eoFl…',
#  'State (Illinois) leadership needs to address #humanservices crisis https://t.co/lA3FS5AI7w',
#  '@Jamie_Post @Bevhillsyeg  Again unheard and no change to #HumanServices for #PwD Disappointed. The Minister is in over his head.',
#  'Let this be the change the #disability community desperately needs. https://t.co/mnHZfqpImX #equality #ableg #HumanServices',
#  '#HumanServices like you’ve never seen it. Imagine the digital #childsupport agency. https://t.co/HcxyvHUy2A https://t.co/4XfwPLmseZ',
#  'What’s leadership got to do with the future of #HumanServices? Find out here https://t.co/RZFYUPvq58 https://t.co/eoFlmAWDhN',
#  '#tiptuesday #healthcare #humanservices #letsgetstarted #consciousservice https://t.co/ningQFdJMX',
#  'Check out 3 digital hotspots for #childsupport services. #HumanServices https://t.co/uknZdGFPan',
#  'Check our our new #blog post! Lessons Learned from our new pilot program &amp; from eight years in #humanservices! https://t.co/xRmeVz9PoA',
#  '#HumanServices 2.0 - InterOptimability: A results-driven process tailored to your team https://t.co/BhheWdUbsU',
#  'Follow us on social media! @LETUHistory. #LETU #history #crimjus #intlstudies #ir #humanservices 📷: https://t.co/SviAyezfjw',
#  'Shout out 2 @SalArmyTampa #counseling &amp; #humanservices #interns providing individual &amp; group… https://t.co/4F9vNbPTM2',
#  'RT @AccenturePubSvc: Check out 3 digital hotspots for #childsupport services. #HumanServices https://t.co/YvUiYZFJlX https://t.co/fPHxR7Zey8',
#  "Started my 6th year as a practicum supervisor for @StevensonU #humanservices seniors. Met 4 great people. I think they'll change the world.",
#  'State (Illinois) leadership needs to address #humanservices crisis https://t.co/EdhxPr1nML',
#  'RT @SDHumanServices: #HumanServices #career, leadership position w/ #DevelopmentalDisabilities, asst. #director: https://t.co/rnL9Uccnqa ht…',
#  'RT @wiscjobs: #Hiring #HumanServices Coordinator to monitor #compliance with #SocialService program rules. $46-64k/yr https://t.co/OG24lNzu…',
#  '#Hiring #HumanServices Coordinator to monitor #compliance with #SocialService program rules. $46-64k/yr https://t.co/OG24lNzuIm #MadisonWI',
#  'Liberal Arts #chemicaldependency #earlychildhood #communication #mediaarts #humanservices https://t.co/ty0EMIDOoo',
#  'https://t.co/xndylOZFGY    #research indicates #importance of #spirituality when delivering #optimal #humanservices https://t.co/0epxM5Gf79',
#  'Check out 3 digital hotspots for #childsupport services. #HumanServices https://t.co/YvUiYZFJlX https://t.co/fPHxR7Zey8',
#  'Want to see what the future of #HumanServices looks like? Find out more https://t.co/ghVpqVpAUa https://t.co/hbbW4HBeKz',
#  "RT @Ostendorff: Open House-Earn your associate, bachelor or master's degree!#emchat #mba #mpa #msed #business #humanservices #health https:…",
#  'RT @AccenturePubSvc: Test yourself: Do you have the 5 traits of adaptive #HumanServices leaders? #HSSummit15 https://t.co/wVuSMfaDGm https:…',
#  '#Radical #social workers, #counselors, #psychologists &amp; other #HumanServices ppl - new Facebook group: https://t.co/3ASJSIR34A',
#  "#humanservices I just listed: 'An Introduction to Human Services', for 14.12 via @amazon https://t.co/A8w0n80SGk",
#  'RT @AccenturePubSvc: How can #HumanServices leaders turn ideas into outcomes? Read here https://t.co/lG69FV5TNI https://t.co/lWnDq0F4Yi',
#  "Open House-Earn your associate, bachelor or master's degree!#emchat #mba #mpa #msed #business #humanservices #health https://t.co/HFT7uo141M",
#  'How can #HumanServices leaders turn ideas into outcomes? Read here https://t.co/ToqMQPOxyC',
#  'Solving for Shelter: Matching Income Volatility with Housing Stability (Blog) https://t.co/zrXAcYQrMP #homelessness #humanservices',
#  'RT @AccenturePubSvc: How can #HumanServices leaders turn ideas into outcomes? Read here https://t.co/lG69FV5TNI https://t.co/lWnDq0F4Yi',
#  'Veterans Home seeks Senior Social Worker/Case Manager \nhttps://t.co/l6kFkwkw9P #humanservices',
#  '#HumanServices 2.0 - InterOptimability: A results-driven process tailored to your team https://t.co/IXmdFBqQvQ',
#  'RT @AccenturePubSvc: How can #HumanServices leaders turn ideas into outcomes? Read here https://t.co/lG69FV5TNI https://t.co/lWnDq0F4Yi',
#  'How can #HumanServices leaders turn ideas into outcomes? Read here https://t.co/lG69FV5TNI https://t.co/lWnDq0F4Yi',
#  '#CDC Funding: Increase Access to Care for Black Men Who Have Sex w/Men https://t.co/2cIxSqpeST #HumanServices #Nonprofit #WhatProfessorsDo',
#  'RT @SDHumanServices: #HumanServices #career, leadership position w/ #DevelopmentalDisabilities, asst. #director: https://t.co/rnL9Uccnqa ht…',
#  '#HumanServices #career, leadership position w/ #DevelopmentalDisabilities, asst. #director: https://t.co/rnL9Uccnqa https://t.co/Nt2uVKp7rR',
#  '#HumanServices 2.0™: A Framework for #Interoperability [PDF] https://t.co/umrITys51v https://t.co/UHDGmALmnJ',
#  'We asked questions so you can get answers about #humanservices #analytics. https://t.co/0BA2o1w8gq',
#  '2015 #HumanServices Summit: strategic steps for generating stronger, healthier individuals, families &amp; communities. https://t.co/Z7pfoYMXKF',
#  "I will probably die due to my 8 week ethics class. if u need me I'll be overthinking ethical decisions. #humanservices #collegelife",
#  '#Grants: Lawrence Foundation (geographic limitations), due April 30, 2016, #environmental #humanservices... https://t.co/xwUzmhL3Tv',
#  '#Grants: Lawrence Foundation (geographic limitations), due April 30, 2016, #environmental #humanservices #disasterrelief...',
#  'Event keynote highlights @UNG_news #HumanServices #ServiceLearning efforts in support of Summer Food program https://t.co/qeFCYPNSZi',
#  '#BellLetsTalk about how after battling mental illnesses i want to help others #humanservices',
#  '#Career opp. w/ #HumanServices in Pierre: #CommunicationsDirector. Check it out! https://t.co/LXzfZjwK2c https://t.co/ar7on8cDXR',
#  'RT @MsToya1913: In #Illinois, real damage is being done to our neediest children and families &amp; to our #humanservices @unitedwaychi\n\nhttps:…',
#  'RT @MsToya1913: In #Illinois, real damage is being done to our neediest children and families &amp; to our #humanservices @unitedwaychi\n\nhttps:…',
#  '#humanservices #1711humanservices #1711FNDN https://t.co/Wua7A1J2KB',
#  '#1711humanservices #humanservices #1711FNDN https://t.co/c2mMId2kg2',
#  '#1711community #1711health #1711humanservices #1711FNDN #humanservices #health https://t.co/iGIqULsKM9',
#  'RT @MsToya1913: In #Illinois, real damage is being done to our neediest children and families &amp; to our #humanservices @unitedwaychi\n\nhttps:…',
#  'In #Illinois, real damage is being done to our neediest children and families &amp; to our #humanservices @unitedwaychi\n\nhttps://t.co/f7GGWl2i3D',
#  'RT @AccenturePubSvc: Get families to economic sustainability faster with #HumanServices #Analytics. Listen to the podcast. https://t.co/oTT…',
#  'RT @AccenturePubSvc: Can #humanservices #analytics replace the caseworker? https://t.co/6ubu0z7g9E https://t.co/6h9vXTS2B2',
#  'RT @AccenturePubSvc: We asked questions so you can get answers about #humanservices #analytics. https://t.co/IXckHPHXqV https://t.co/wP50SY…',
#  '#HumanServices 2.0™: A Framework for #Interoperability [PDF] https://t.co/xOMhcht5C5 https://t.co/RL2YDaNoGT',
#  '@johnkeypm Sounds like a Wall Street trader - not the Prime Mininster of a Social Democracy. #humanservices #altruisim #nzisnotacorporation',
#  'Sound off! What #legal questions have you come across in your #nonprofit work?#philanthropy #charity #socialwork #humanservices',
#  'RT @AccenturePubSvc: Get families to economic sustainability faster with #HumanServices #Analytics. Listen to the podcast. https://t.co/oTT…',
#  'Need to remember this on a daily... Especially now in my new journey in #humanservices… https://t.co/jJa4HgOgB8',
#  'Get families to economic sustainability faster with #HumanServices #Analytics. Listen to the podcast. https://t.co/oTTljWI8DK',
#  'We asked questions so you can get answers about #humanservices #analytics. https://t.co/IXckHPHXqV https://t.co/wP50SYDUUl',
#  'RT @AccenturePubSvc: Can #humanservices #analytics replace the caseworker? https://t.co/6ubu0z7g9E https://t.co/6h9vXTS2B2',
#  'Off to school I go #Humanservices',
#  'You can only give what you have, you can only teach what you know #judsonawesome #humanservices #helpingprofessions #newmasters',
#  '#Grants: Community Building Grants, United Way of Greater Houston, due April 11, 2016 #health #community #humanservices...',
#  "IL Rep Greg Harris &amp; PACPI's Exec Director Anne Statton will be speaking at a #news conference on crisis for #humanservices this afternoon",
#  'Can #humanservices #analytics replace the caseworker? https://t.co/6ubu0z7g9E https://t.co/6h9vXTS2B2',
#  'RT @MetroFamChicago: Rally for #humanservices tomorrow! State of OUR State, Springfield Capitol, 11 am this Wednesday. #twill #SOS https://…',
#  'Rally for #humanservices tomorrow! State of OUR State, Springfield Capitol, 11 am this Wednesday. #twill #SOS https://t.co/pUwQi65rno']
